# %%
import pandas as pd
from docx import Document

# Step 1: Load akc-data-latest.csv
akc_df = pd.read_csv("akc-data-latest.csv")

# Step 2: Load Таблица животных (2).docx
doc = Document("Таблица животных (2).docx")

# Extract the table data
table = doc.tables[0]
data = []
for row in table.rows:
    data.append([cell.text.strip() for cell in row.cells])

# Convert to DataFrame
disease_counts_df = pd.DataFrame(data[1:], columns=data[0])

# Step 3: Map Russian breed names to English (for merging)
breed_translation = {
    'Йоркширские терьеры': 'Yorkshire Terrier',
    'Немецкая овчарка': 'German Shepherd Dog',
    'Тойтерьер': 'Russian Toy',  # Corrected mapping
    'Чихуахуа': 'Chihuahua',
    'Шпиц немецкий': 'German Spitz',
    'Шпиц померанский': 'Pomeranian',
    'Алабай': 'Central Asian Shepherd Dog',
    'Хаски': 'Siberian Husky',
    'Мопс': 'Pug',
    'Французский бульдог': 'French Bulldog',
    'Пекинес': 'Pekingese',
    'Такса': 'Dachshund',
    'Спаниель': 'Cocker Spaniel',
    'Питбультерьер': 'American Pit Bull Terrier',
    'Джек-рассел-терьер': 'Jack Russell Terrier',
    'Пудель': 'Poodle',
    'Русский спаниель': 'Russian Spaniel',
    'Карликовый пинчер': 'Miniature Pinscher',
    'Мальтипу': 'Maltipoo',
    'Шарпей': 'Chinese Shar-Pei',
    'Стаффордшир-терьер': 'Staffordshire Bull Terrier',
    'Ротвейлер': 'Rottweiler',
    'Лабрадор': 'Labrador Retriever'
}

# Apply translation mapping
disease_counts_df['Breed'] = disease_counts_df['Порода'].map(breed_translation)

# Step 4: Merge the datasets
merged_df = pd.merge(disease_counts_df, akc_df, on='Breed', how='left')

# Output merged dataset preview
merged_df
# Out:
#                  Порода Количество по базе Уролитиаз/МКБ  \
# 0   Йоркширские терьеры                571            18
# 1      Немецкая овчарка                715             3
# 2             Тойтерьер                362             7
# 3              Чихуахуа                227             3
# 4         Шпиц немецкий                107             3
# 5      Шпиц померанский                103             2
# 6                Алабай                194             1
# 7                 Хаски                208             3
# 8                  Мопс                201            14
# 9   Французский бульдог                197             0
# 10              Пекинес                159             2
# 11                Такса                149           2+1
# 12             Спаниель                121             0
# 13        Питбультерьер                110             1
# 14   Джек-рассел-терьер                 88             0
# 15               Пудель                 73           1+1
# 16     Русский спаниель                 82             0
# 17    Карликовый пинчер                 61             1
# 18             Мальтипу                 65             0
# 19               Шарпей                 63             1
# 20   Стаффордшир-терьер                 55             0
# 21            Ротвейлер                 50             0
# 22             Лабрадор                275             2
#
#    Энетропатии и гастропатии (в том числе инфекционные) Панкреатит  \
# 0                                                 111           63
# 1                                       3+3+11+157+12            4
# 2                                         3+24+22+1+5           25
# 3                                           10+5+1+20           23
# 4                                               3+7+4            5
# 5                                         2+3+2+8+6+2            6
# 6                                            5+2+35+3            2
# 7                                              3+3+32            3
# 8                                              10+4+6            5
# 9                                            7+3+2+12            5
# 10                                             10+2+7            6
# 11                                            7+1+2+6           12
# 12                                           4+1+1+18            3
# 13                                             1+1+11            0
# 14                                                2+3            4
# 15                                            4+2+2+2            5
# 16                                              2+1+7            1
# 17                                              3+1+5            3
# 18                                                2+2            2
# 19                                                2+6            1
# 20                                              1+2+2            3
# 21                                                  9            1
# 22                                               7+25            3
#
#    Гепатопатии ХБП Сахарный диабет Ожирение                       Breed  ...  \
# 0            4  13               4       12           Yorkshire Terrier  ...
# 1            1   5               3        3         German Shepherd Dog  ...
# 2            1   4               2       12                 Russian Toy  ...
# 3            0   0               0       10                   Chihuahua  ...
# 4            0   0               0        2                German Spitz  ...
# 5            0   0               0        2                  Pomeranian  ...
# 6            1   1               0        0  Central Asian Shepherd Dog  ...
# 7            0   4               1        1              Siberian Husky  ...
# 8            0   0               0       14                         Pug  ...
# 9            0   0               0        1              French Bulldog  ...
# 10           0   1               0        0                   Pekingese  ...
# 11           0   0               2        7                   Dachshund  ...
# 12           0   0               0        4              Cocker Spaniel  ...
# 13           0   0               0        0   American Pit Bull Terrier  ...
# 14           0   0               0        0        Jack Russell Terrier  ...
# 15           1   0               2        0                      Poodle  ...
# 16           0   0               0        0             Russian Spaniel  ...
# 17           0   0               2        2          Miniature Pinscher  ...
# 18           0   0               0        0                    Maltipoo  ...
# 19           0   0               0        0            Chinese Shar-Pei  ...
# 20           0   0               0        1  Staffordshire Bull Terrier  ...
# 21           0   0               0        1                  Rottweiler  ...
# 22           0   1               3        5          Labrador Retriever  ...
#
#    grooming_frequency_value grooming_frequency_category shedding_value  \
# 0                       1.0      Specialty/Professional            0.2
# 1                       0.4             Weekly Brushing            0.8
# 2                       0.4             Weekly Brushing            0.2
# 3                       0.2       Occasional Bath/Brush            0.4
# 4                       0.6   2-3 Times a Week Brushing            0.6
# 5                       0.6   2-3 Times a Week Brushing            0.6
# 6                       0.2       Occasional Bath/Brush            0.6
# 7                       0.4             Weekly Brushing            0.6
# 8                       0.4             Weekly Brushing            0.8
# 9                       0.2       Occasional Bath/Brush            0.8
# 10                      0.6   2-3 Times a Week Brushing            0.6
# 11                      0.4             Weekly Brushing            0.4
# 12                      0.8              Daily Brushing            0.4
# 13                      NaN                         NaN            NaN
# 14                      NaN                         NaN            NaN
# 15                      NaN                         NaN            NaN
# 16                      NaN                         NaN            NaN
# 17                      0.2       Occasional Bath/Brush            0.2
# 18                      NaN                         NaN            NaN
# 19                      0.2       Occasional Bath/Brush            0.8
# 20                      0.4             Weekly Brushing            0.4
# 21                      0.4             Weekly Brushing            0.6
# 22                      0.4             Weekly Brushing            0.8
#
#     shedding_category  energy_level_value   energy_level_category  \
# 0          Infrequent                 0.6        Regular Exercise
# 1           Regularly                 0.6        Regular Exercise
# 2          Infrequent                 0.6        Regular Exercise
# 3          Occasional                 0.6        Regular Exercise
# 4            Seasonal                 0.6        Regular Exercise
# 5            Seasonal                 0.6        Regular Exercise
# 6            Seasonal                 0.4                    Calm
# 7            Seasonal                 0.8               Energetic
# 8           Regularly                 0.6        Regular Exercise
# 9           Regularly                 0.4                    Calm
# 10           Seasonal                 0.4                    Calm
# 11         Occasional                 0.6        Regular Exercise
# 12         Occasional                 0.6        Regular Exercise
# 13                NaN                 NaN                     NaN
# 14                NaN                 NaN                     NaN
# 15                NaN                 NaN                     NaN
# 16                NaN                 NaN                     NaN
# 17         Infrequent                 0.6        Regular Exercise
# 18                NaN                 NaN                     NaN
# 19          Regularly                 0.6        Regular Exercise
# 20         Occasional                 0.8               Energetic
# 21           Seasonal                 0.6        Regular Exercise
# 22          Regularly                 1.0  Needs Lots of Activity
#
#     trainability_value  trainability_category  demeanor_value  \
# 0                  0.2        May be Stubborn             0.8
# 1                  1.0        Eager to Please             0.6
# 2                  0.6              Agreeable             0.8
# 3                  0.4            Independent             0.6
# 4                  1.0        Eager to Please             0.4
# 5                  0.6              Agreeable             0.6
# 6                  0.4            Independent             0.2
# 7                  0.4            Independent             0.8
# 8                  0.6              Agreeable             0.8
# 9                  0.6              Agreeable             0.6
# 10                 0.2        May be Stubborn             0.4
# 11                 0.6              Agreeable             0.6
# 12                 1.0        Eager to Please             1.0
# 13                 NaN                    NaN             NaN
# 14                 NaN                    NaN             NaN
# 15                 NaN                    NaN             NaN
# 16                 NaN                    NaN             NaN
# 17                 0.4            Independent             0.6
# 18                 NaN                    NaN             NaN
# 19                 0.2        May be Stubborn             0.4
# 20                 0.2        May be Stubborn             0.8
# 21                 0.6              Agreeable             0.4
# 22                 1.0        Eager to Please             1.0
#
#           demeanor_category
# 0                  Friendly
# 1          Alert/Responsive
# 2                  Friendly
# 3          Alert/Responsive
# 4   Reserved with Strangers
# 5          Alert/Responsive
# 6                Aloof/Wary
# 7                  Friendly
# 8                  Friendly
# 9          Alert/Responsive
# 10  Reserved with Strangers
# 11         Alert/Responsive
# 12                 Outgoing
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17         Alert/Responsive
# 18                      NaN
# 19  Reserved with Strangers
# 20                 Friendly
# 21  Reserved with Strangers
# 22                 Outgoing
#
# [23 rows x 30 columns]

# %%
disease_cols = [
    'Уролитиаз/МКБ',
    'Энетропатии и гастропатии (в том числе инфекционные)',
    'Панкреатит',
    'Гепатопатии',
    'ХБП',
    'Сахарный диабет',
    'Ожирение'
]

melted_df = merged_df.melt(
    id_vars=['Breed'],  
    value_vars=disease_cols,
    var_name='Disease',  
    value_name='Count'   
)

melted_df = melted_df[melted_df['Count'].notna()]

# %%
melted_df
# Out:
#                           Breed        Disease Count
# 0             yorkshire terrier  Уролитиаз/МКБ    18
# 1           german shepherd dog  Уролитиаз/МКБ     3
# 2                   russian toy  Уролитиаз/МКБ     7
# 3                     chihuahua  Уролитиаз/МКБ     3
# 4                  german spitz  Уролитиаз/МКБ     3
# ..                          ...            ...   ...
# 156                    maltipoo       Ожирение     0
# 157            chinese shar-pei       Ожирение     0
# 158  staffordshire bull terrier       Ожирение     1
# 159                  rottweiler       Ожирение     1
# 160          labrador retriever       Ожирение     5
#
# [161 rows x 3 columns]

# %%
melted_df.to_csv("table.csv")

# %%
import typing
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrapeDataFromSpreadsheet() -> typing.List[typing.List[str]]:
    html = requests.get(
        'https://docs.google.com/spreadsheets/d/1S14i0IK-bwM_17vhphjfUJEJq-4TMtxMLrlGQ_8JcC8/gviz/tq?tqx=out:html&tq&gid=1'
    ).text
    soup = BeautifulSoup(html, 'html.parser')
    # The Google Sheets data is presented as a single table in the rendered HTML:
    table = soup.find_all('table')[0]
    # Extract row data (list of lists)
    rows = [
        [td.text.strip() for td in row.find_all("td")]
        for row in table.find_all('tr')
    ]
    return rows

def rows_to_dataframe(rows: typing.List[typing.List[str]]) -> pd.DataFrame:
    # Make sure there’s at least one row to treat as a header
    if not rows:
        return pd.DataFrame()  # empty DataFrame if no data
    
    # If the first row is the header, separate it out
    header = rows[0]
    data = rows[1:]
    
    # Create a DataFrame
    df = pd.DataFrame(data, columns=header)
    return df

if __name__ == "__main__":
    rows = scrapeDataFromSpreadsheet()
    df = rows_to_dataframe(rows)
    print(df.head())
# Out:
#
# 0                             Disorder         Disease          Breed
# 1              Inherited eye disorders       Cataracts  Affenpinscher
# 2  Inherited musculoskeletal disorders   Hip dysplasia  Affenpinscher
# 3        Inherited endocrine disorders  Hypothyroidism   Afghan hound
# 4              Inherited eye disorders       Cataracts   Afghan hound

# %%
headers = df.iloc[0]
new_df  = pd.DataFrame(df.values[1:], columns=headers)
new_df['Breed'] = new_df['Breed'].str.lower()
new_df
# Out:
# 0                                Disorder                   Disease  \
# 0                 Inherited eye disorders                 Cataracts
# 1     Inherited musculoskeletal disorders             Hip dysplasia
# 2           Inherited endocrine disorders            Hypothyroidism
# 3                 Inherited eye disorders                 Cataracts
# 4                 Inherited eye disorders         Retinal dysplasia
# ...                                   ...                       ...
# 1644   Inherited nervous system disorders       Shaker dog syndrome
# 1645      Inherited respiratory disorders         tracheal collapse
# 1646             Inherited skin disorders  colour dilution alopecia
# 1647             Inherited skin disorders  congenital hypotrichosis
# 1648             Inherited skin disorders             dermoid sinus
#
# 0                 Breed
# 0         affenpinscher
# 1         affenpinscher
# 2          afghan hound
# 3          afghan hound
# 4          afghan hound
# ...                 ...
# 1644  yorkshire terrier
# 1645  yorkshire terrier
# 1646  yorkshire terrier
# 1647  yorkshire terrier
# 1648  yorkshire terrier
#
# [1649 rows x 3 columns]

# %%
melted_df = melted_df[melted_df['Count'].notna()]
melted_df['Breed'] = melted_df['Breed'].str.lower()


final_df = pd.merge(melted_df, new_df, on='Breed', how='left')

print(final_df.head())
# Out:
#                Breed      Disease_x Count  \
# 0  yorkshire terrier  Уролитиаз/МКБ    18
# 1  yorkshire terrier  Уролитиаз/МКБ    18
# 2  yorkshire terrier  Уролитиаз/МКБ    18
# 3  yorkshire terrier  Уролитиаз/МКБ    18
# 4  yorkshire terrier  Уролитиаз/МКБ    18
#
#                                             Disorder  \
# 0                 Inherited cardiovascular disorders
# 1                 Inherited cardiovascular disorders
# 2  Inherited disorders of the urinary and reprodu...
# 3  Inherited disorders of the urinary and reprodu...
# 4                      Inherited endocrine disorders
#
#                                    Disease_y
# 0             Patent ductus arteriosus (PDA)
# 1                        Portosystemic shunt
# 2          Cryptorchidism, retained testicle
# 3                      Urolithiasis (stones)
# 4  Hyperadrenocorticism (Cushing's syndrome)

# %%
final_df
# Out:
#                    Breed      Disease_x Count  \
# 0      yorkshire terrier  Уролитиаз/МКБ    18
# 1      yorkshire terrier  Уролитиаз/МКБ    18
# 2      yorkshire terrier  Уролитиаз/МКБ    18
# 3      yorkshire terrier  Уролитиаз/МКБ    18
# 4      yorkshire terrier  Уролитиаз/МКБ    18
# ...                  ...            ...   ...
# 1584  labrador retriever       Ожирение     5
# 1585  labrador retriever       Ожирение     5
# 1586  labrador retriever       Ожирение     5
# 1587  labrador retriever       Ожирение     5
# 1588  labrador retriever       Ожирение     5
#
#                                                Disorder  \
# 0                    Inherited cardiovascular disorders
# 1                    Inherited cardiovascular disorders
# 2     Inherited disorders of the urinary and reprodu...
# 3     Inherited disorders of the urinary and reprodu...
# 4                         Inherited endocrine disorders
# ...                                                 ...
# 1584                           Inherited skin disorders
# 1585                           Inherited skin disorders
# 1586                           Inherited skin disorders
# 1587                           Inherited skin disorders
# 1588                           Inherited skin disorders
#
#                                       Disease_y
# 0                Patent ductus arteriosus (PDA)
# 1                           Portosystemic shunt
# 2             Cryptorchidism, retained testicle
# 3                         Urolithiasis (stones)
# 4     Hyperadrenocorticism (Cushing's syndrome)
# ...                                         ...
# 1584                                      Atopy
# 1585                                 Lymphedema
# 1586                         sebaceous adenitis
# 1587                                  seborrhea
# 1588            vitamin A-responsive dermatosis
#
# [1589 rows x 5 columns]

# %%
final_df.to_csv("qq.csv")

# %%
import pandas as pd
from docx import Document

# === Step 1: Load akc-data-latest.csv ===
akc_df = pd.read_csv("akc-data-latest.csv")

# === Step 2: Load Таблица животных (2).docx ===
doc = Document("Таблица животных (2).docx")
table = doc.tables[0]
data = []
for row in table.rows:
    data.append([cell.text.strip() for cell in row.cells])
disease_counts_df = pd.DataFrame(data[1:], columns=data[0])

# === Step 3: Map Russian breed names to English ===
breed_translation = {
    'Йоркширские терьеры': 'Yorkshire Terrier',
    'Немецкая овчарка': 'German Shepherd Dog',
    'Тойтерьер': 'Russian Toy',
    'Чихуахуа': 'Chihuahua',
    'Шпиц немецкий': 'German Spitz',
    'Шпиц померанский': 'Pomeranian',
    'Алабай': 'Central Asian Shepherd Dog',
    'Хаски': 'Siberian Husky',
    'Мопс': 'Pug',
    'Французский бульдог': 'French Bulldog',
    'Пекинес': 'Pekingese',
    'Такса': 'Dachshund',
    'Спаниель': 'Cocker Spaniel',
    'Питбультерьер': 'American Pit Bull Terrier',
    'Джек-рассел-терьер': 'Jack Russell Terrier',
    'Пудель': 'Poodle',
    'Русский спаниель': 'Russian Spaniel',
    'Карликовый пинчер': 'Miniature Pinscher',
    'Мальтипу': 'Maltipoo',
    'Шарпей': 'Chinese Shar-Pei',
    'Стаффордшир-терьер': 'Staffordshire Bull Terrier',
    'Ротвейлер': 'Rottweiler',
    'Лабрадор': 'Labrador Retriever'
}
disease_counts_df['Breed'] = disease_counts_df['Порода'].map(breed_translation)

# === Step 4: Melt diseases ===
disease_cols = [
    'Уролитиаз/МКБ',
    'Энетропатии и гастропатии (в том числе инфекционные)',
    'Панкреатит',
    'Гепатопатии',
    'ХБП',
    'Сахарный диабет',
    'Ожирение'
]

melted_df = disease_counts_df.melt(
    id_vars=['Breed'],
    value_vars=disease_cols,
    var_name='Disease_RU',
    value_name='Count'
)
melted_df = melted_df[melted_df['Count'].notna()]

# === Step 5: Map Russian diseases to English ===
disease_translation = {
    'Уролитиаз/МКБ': ['Urolithiasis (stones)'],
    'Энетропатии и гастропатии (в том числе инфекционные)': [
        'Immunoproliferative enteropathy (Basenji)',
        'Gluten-sensitive enteropathy',
        'Protein-losing enteropathy'
    ],
    'Панкреатит': ['Pancreatitis'],
    'Гепатопатии': ['Chronic hepatitis'],
    'ХБП': ['Familial kidney disease'],
    'Сахарный диабет': ['Diabetes mellitus'],
    'Ожирение': ['Obesity']
}

# === Step 6: Expand rows where diseases map to multiple English terms ===
expanded_rows = []
for _, row in melted_df.iterrows():
    eng_diseases = disease_translation.get(row['Disease_RU'], [])
    for disease in eng_diseases:
        expanded_rows.append({
            'Breed': row['Breed'],
            'Disease': disease,
            'Count': row['Count']
        })
translated_df = pd.DataFrame(expanded_rows)

# === Step 7: Merge with akc_df ===
final_df = pd.merge(translated_df, akc_df, on='Breed', how='left')

# === Output the result ===
final_df
# Out:
#                           Breed                Disease Count  \
# 0             Yorkshire Terrier  Urolithiasis (stones)    18
# 1           German Shepherd Dog  Urolithiasis (stones)     3
# 2                   Russian Toy  Urolithiasis (stones)     7
# 3                     Chihuahua  Urolithiasis (stones)     3
# 4                  German Spitz  Urolithiasis (stones)     3
# ..                          ...                    ...   ...
# 202                    Maltipoo                Obesity     0
# 203            Chinese Shar-Pei                Obesity     0
# 204  Staffordshire Bull Terrier                Obesity     1
# 205                  Rottweiler                Obesity     1
# 206          Labrador Retriever                Obesity     5
#
#                                            description  \
# 0    The Yorkshire Terrier is a compact, toy-size t...
# 1    German Shepherd Dogs can stand as high as 26 i...
# 2    The Russian Toy is a toy breed with a lineage ...
# 3    The Chihuahua is a balanced, graceful dog of t...
# 4    Spitz breeds like the German Spitz are captiva...
# ..                                                 ...
# 202                                                NaN
# 203  The compact, medium-sized Chinese Shar-Pei is ...
# 204  At 14 to 16 inches, Staffordshire Bull Terrier...
# 205  A male Rottweiler will stand anywhere from 24 ...
# 206  The sturdy, well-balanced Labrador Retriever c...
#
#                             temperament popularity  min_height  max_height  \
# 0    Affectionate, Sprightly, Tomboyish         10       17.78       20.32
# 1          Confident, Courageous, Smart          2       55.88       66.04
# 2                Loyal, Smart, Charming        NaN       20.32       27.94
# 3             Charming, Graceful, Sassy         33       12.70       20.32
# 4            Devoted, Lively, Attentive        NaN       30.48       38.10
# ..                                  ...        ...         ...         ...
# 202                                 NaN        NaN         NaN         NaN
# 203            Loyal, Independent, Calm         64       45.72       50.80
# 204            Clever, Brave, Tenacious         80       35.56       40.64
# 205   Loyal, Loving, Confident Guardian          8       55.88       68.58
# 206          Friendly, Active, Outgoing          1       54.61       62.23
#
#      min_weight  max_weight  ...  grooming_frequency_value  \
# 0      3.175147    3.175147  ...                       1.0
# 1     22.679619   40.823313  ...                       0.4
# 2      2.948350    2.948350  ...                       0.4
# 3      2.721554    2.721554  ...                       0.2
# 4     10.886217   11.793402  ...                       0.6
# ..          ...         ...  ...                       ...
# 202         NaN         NaN  ...                       NaN
# 203   20.411657   27.215542  ...                       0.2
# 204   10.886217   17.236510  ...                       0.4
# 205   36.287390   61.234970  ...                       0.4
# 206   24.947580   36.287390  ...                       0.4
#
#      grooming_frequency_category shedding_value  shedding_category  \
# 0         Specialty/Professional            0.2         Infrequent
# 1                Weekly Brushing            0.8          Regularly
# 2                Weekly Brushing            0.2         Infrequent
# 3          Occasional Bath/Brush            0.4         Occasional
# 4      2-3 Times a Week Brushing            0.6           Seasonal
# ..                           ...            ...                ...
# 202                          NaN            NaN                NaN
# 203        Occasional Bath/Brush            0.8          Regularly
# 204              Weekly Brushing            0.4         Occasional
# 205              Weekly Brushing            0.6           Seasonal
# 206              Weekly Brushing            0.8          Regularly
#
#     energy_level_value   energy_level_category trainability_value  \
# 0                  0.6        Regular Exercise                0.2
# 1                  0.6        Regular Exercise                1.0
# 2                  0.6        Regular Exercise                0.6
# 3                  0.6        Regular Exercise                0.4
# 4                  0.6        Regular Exercise                1.0
# ..                 ...                     ...                ...
# 202                NaN                     NaN                NaN
# 203                0.6        Regular Exercise                0.2
# 204                0.8               Energetic                0.2
# 205                0.6        Regular Exercise                0.6
# 206                1.0  Needs Lots of Activity                1.0
#
#      trainability_category demeanor_value        demeanor_category
# 0          May be Stubborn            0.8                 Friendly
# 1          Eager to Please            0.6         Alert/Responsive
# 2                Agreeable            0.8                 Friendly
# 3              Independent            0.6         Alert/Responsive
# 4          Eager to Please            0.4  Reserved with Strangers
# ..                     ...            ...                      ...
# 202                    NaN            NaN                      NaN
# 203        May be Stubborn            0.4  Reserved with Strangers
# 204        May be Stubborn            0.8                 Friendly
# 205              Agreeable            0.4  Reserved with Strangers
# 206        Eager to Please            1.0                 Outgoing
#
# [207 rows x 23 columns]

# %%
final_df.to_csv('start.csv')

# %%
import typing
import requests
from bs4 import BeautifulSoup
import pandas as pd

# === 1. Scrape Google Spreadsheet ===
def scrapeDataFromSpreadsheet() -> typing.List[typing.List[str]]:
    html = requests.get(
        'https://docs.google.com/spreadsheets/d/1S14i0IK-bwM_17vhphjfUJEJq-4TMtxMLrlGQ_8JcC8/gviz/tq?tqx=out:html&tq&gid=1'
    ).text
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find_all('table')[0]
    rows = [
        [td.text.strip() for td in row.find_all("td")]
        for row in table.find_all('tr')
    ]
    return rows

def rows_to_dataframe(rows: typing.List[typing.List[str]]) -> pd.DataFrame:
    if not rows:
        return pd.DataFrame()
    header = rows[0]
    data = rows[1:]
    return pd.DataFrame(data, columns=header)

# Scrape and clean Google Sheet
rows = scrapeDataFromSpreadsheet()
df = rows_to_dataframe(rows)

# Some rows may be empty; drop them
df = df.dropna(how='all')

# Handle header duplication (first row is header again)
headers = df.iloc[0]
google_df = pd.DataFrame(df.values[1:], columns=headers)

# Clean breed and disease columns for merging
google_df['Breed'] = google_df['Breed'].str.lower().str.strip()
google_df['Disease'] = google_df['Disease'].str.strip()

# === 2. Load Local Data (assuming translated_df from previous step) ===
# translated_df should have 'Breed', 'Disease', 'Count' columns from your previous code.

# Ensure breeds and diseases are lowercase and stripped for consistent merging
translated_df['Breed'] = translated_df['Breed'].str.lower().str.strip()
translated_df['Disease'] = translated_df['Disease'].str.strip()

# === 3. Merge on Breed and Disease/Disorder ===
merged_df = pd.merge(
    translated_df,
    google_df,
    left_on=['Breed', 'Disease'],
    right_on=['Breed', 'Disease'],
    how='left'
)

# === 4. View Result ===
print(merged_df.head())
# Out:
#                  Breed                Disease Count  \
# 0    yorkshire terrier  Urolithiasis (stones)    18
# 1  german shepherd dog  Urolithiasis (stones)     3
# 2          russian toy  Urolithiasis (stones)     7
# 3            chihuahua  Urolithiasis (stones)     3
# 4         german spitz  Urolithiasis (stones)     3
#
#                                             Disorder
# 0  Inherited disorders of the urinary and reprodu...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
merged_df
# Out:
#                           Breed                Disease Count  \
# 0             yorkshire terrier  Urolithiasis (stones)    18
# 1           german shepherd dog  Urolithiasis (stones)     3
# 2                   russian toy  Urolithiasis (stones)     7
# 3                     chihuahua  Urolithiasis (stones)     3
# 4                  german spitz  Urolithiasis (stones)     3
# ..                          ...                    ...   ...
# 202                    maltipoo                Obesity     0
# 203            chinese shar-pei                Obesity     0
# 204  staffordshire bull terrier                Obesity     1
# 205                  rottweiler                Obesity     1
# 206          labrador retriever                Obesity     5
#
#                                               Disorder
# 0    Inherited disorders of the urinary and reprodu...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
# [207 rows x 4 columns]

# %%
merged_df.to_csv('dd.csv')
