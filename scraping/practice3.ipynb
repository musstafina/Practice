# %%
import typing
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrapeDataFromSpreadsheet() -> typing.List[typing.List[str]]:
    html = requests.get(
        'https://docs.google.com/spreadsheets/d/1S14i0IK-bwM_17vhphjfUJEJq-4TMtxMLrlGQ_8JcC8/gviz/tq?tqx=out:html&tq&gid=1'
    ).text
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find_all('table')[0]
    rows = [
        [td.text.strip() for td in row.find_all("td")]
        for row in table.find_all('tr')
    ]
    return rows

def rows_to_dataframe(rows: typing.List[typing.List[str]]) -> pd.DataFrame:
    if not rows:
        return pd.DataFrame()  
    
    header = rows[0]
    data = rows[1:]
    
    df = pd.DataFrame(data, columns=header)
    return df

if __name__ == "__main__":
    rows = scrapeDataFromSpreadsheet()
    df = rows_to_dataframe(rows)
    print(df.head())
# Out:
#
# 0                             Disorder         Disease          Breed
# 1              Inherited eye disorders       Cataracts  Affenpinscher
# 2  Inherited musculoskeletal disorders   Hip dysplasia  Affenpinscher
# 3        Inherited endocrine disorders  Hypothyroidism   Afghan hound
# 4              Inherited eye disorders       Cataracts   Afghan hound

# %%
headers = df.iloc[0]
new_df  = pd.DataFrame(df.values[1:], columns=headers)
new_df['Breed'] = new_df['Breed'].str.lower()
new_df
# Out:
# 0                                Disorder                   Disease  \
# 0                 Inherited eye disorders                 Cataracts
# 1     Inherited musculoskeletal disorders             Hip dysplasia
# 2           Inherited endocrine disorders            Hypothyroidism
# 3                 Inherited eye disorders                 Cataracts
# 4                 Inherited eye disorders         Retinal dysplasia
# ...                                   ...                       ...
# 1644   Inherited nervous system disorders       Shaker dog syndrome
# 1645      Inherited respiratory disorders         tracheal collapse
# 1646             Inherited skin disorders  colour dilution alopecia
# 1647             Inherited skin disorders  congenital hypotrichosis
# 1648             Inherited skin disorders             dermoid sinus
#
# 0                 Breed
# 0         affenpinscher
# 1         affenpinscher
# 2          afghan hound
# 3          afghan hound
# 4          afghan hound
# ...                 ...
# 1644  yorkshire terrier
# 1645  yorkshire terrier
# 1646  yorkshire terrier
# 1647  yorkshire terrier
# 1648  yorkshire terrier
#
# [1649 rows x 3 columns]

# %%
breeds = pd.read_csv('akc-data-latest.csv')
breeds['Breed'] = breeds['Breed'].str.lower()
breeds
# Out:
#                  Breed                                        description  \
# 0        affenpinscher  The Affen’s apish look has been described many...
# 1         afghan hound  The Afghan Hound is an ancient breed, his whol...
# 2     airedale terrier  The Airedale Terrier is the largest of all ter...
# 3                akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4     alaskan malamute  The Alaskan Malamute stands 23 to 25 inches at...
# ..                 ...                                                ...
# 272  wirehaired vizsla  WVs are close relatives of Vizslas but a disti...
# 273     working kelpie  The overall appearance of the Working Kelpie i...
# 274     xoloitzcuintli  The Xoloitzcuintli (show-low-eats-queen-tlee) ...
# 275     yakutian laika  For centuries the Yakutian Laika was an irrepl...
# 276  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
#
#                                    temperament popularity  min_height  \
# 0          Confident, Famously Funny, Fearless        148       22.86
# 1    Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2                 Friendly, Clever, Courageous         60       58.42
# 3      Courageous, Dignified, Profoundly Loyal         47       60.96
# 4                 Affectionate, Loyal, Playful         58       58.42
# ..                                         ...        ...         ...
# 272                   Gentle, Loyal, Trainable        167       54.61
# 273                  Alert, Eager, Intelligent        NaN       48.26
# 274                         Loyal, Alert, Calm        140       25.40
# 275          Affectionate, Intelligent, Active        NaN       53.34
# 276         Affectionate, Sprightly, Tomboyish         10       17.78
#
#      max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0         29.21    3.175147    4.535924            12.0            15.0  ...
# 1         68.58   22.679619   27.215542            12.0            15.0  ...
# 2         58.42   22.679619   31.751466            11.0            14.0  ...
# 3         71.12   31.751466   58.967008            10.0            13.0  ...
# 4         63.50   34.019428   38.555351            10.0            14.0  ...
# ..          ...         ...         ...             ...             ...  ...
# 272       63.50   20.411657   29.483504            12.0            14.0  ...
# 273       63.50   12.700586   27.215542            12.0            15.0  ...
# 274       58.42    4.535924   24.947580            13.0            18.0  ...
# 275       58.42   18.143695   24.947580            10.0            12.0  ...
# 276       20.32    3.175147    3.175147            11.0            15.0  ...
#
#     grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                        0.6    2-3 Times a Week Brushing            0.6
# 1                        0.8               Daily Brushing            0.2
# 2                        0.6    2-3 Times a Week Brushing            0.4
# 3                        0.8               Daily Brushing            0.6
# 4                        0.6    2-3 Times a Week Brushing            0.6
# ..                       ...                          ...            ...
# 272                      0.2        Occasional Bath/Brush            0.6
# 273                      0.2        Occasional Bath/Brush            0.6
# 274                      0.2        Occasional Bath/Brush            0.2
# 275                      0.4              Weekly Brushing            0.6
# 276                      1.0       Specialty/Professional            0.2
#
#      shedding_category energy_level_value  energy_level_category  \
# 0             Seasonal                0.6       Regular Exercise
# 1           Infrequent                0.8              Energetic
# 2           Occasional                0.6       Regular Exercise
# 3             Seasonal                0.8              Energetic
# 4             Seasonal                0.8              Energetic
# ..                 ...                ...                    ...
# 272           Seasonal                0.8              Energetic
# 273           Seasonal                0.8              Energetic
# 274         Infrequent                0.8              Energetic
# 275           Seasonal                0.8              Energetic
# 276         Infrequent                0.6       Regular Exercise
#
#     trainability_value  trainability_category demeanor_value  \
# 0                  0.8          Easy Training            1.0
# 1                  0.2        May be Stubborn            0.2
# 2                  1.0        Eager to Please            0.8
# 3                  1.0        Eager to Please            0.6
# 4                  0.4            Independent            0.8
# ..                 ...                    ...            ...
# 272                0.6              Agreeable            0.6
# 273                0.4            Independent            0.6
# 274                0.6              Agreeable            0.6
# 275                0.2        May be Stubborn            0.4
# 276                0.2        May be Stubborn            0.8
#
#            demeanor_category
# 0                   Outgoing
# 1                 Aloof/Wary
# 2                   Friendly
# 3           Alert/Responsive
# 4                   Friendly
# ..                       ...
# 272         Alert/Responsive
# 273         Alert/Responsive
# 274         Alert/Responsive
# 275  Reserved with Strangers
# 276                 Friendly
#
# [277 rows x 21 columns]

# %%
merged_df = pd.merge(new_df, breeds, on='Breed', how='inner')
merged_df
# Out:
#                                  Disorder                   Disease  \
# 0                 Inherited eye disorders                 Cataracts
# 1     Inherited musculoskeletal disorders             Hip dysplasia
# 2           Inherited endocrine disorders            Hypothyroidism
# 3                 Inherited eye disorders                 Cataracts
# 4                 Inherited eye disorders         Retinal dysplasia
# ...                                   ...                       ...
# 1242   Inherited nervous system disorders       Shaker dog syndrome
# 1243      Inherited respiratory disorders         tracheal collapse
# 1244             Inherited skin disorders  colour dilution alopecia
# 1245             Inherited skin disorders  congenital hypotrichosis
# 1246             Inherited skin disorders             dermoid sinus
#
#                   Breed                                        description  \
# 0         affenpinscher  The Affen’s apish look has been described many...
# 1         affenpinscher  The Affen’s apish look has been described many...
# 2          afghan hound  The Afghan Hound is an ancient breed, his whol...
# 3          afghan hound  The Afghan Hound is an ancient breed, his whol...
# 4          afghan hound  The Afghan Hound is an ancient breed, his whol...
# ...                 ...                                                ...
# 1242  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
# 1243  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
# 1244  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
# 1245  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
# 1246  yorkshire terrier  The Yorkshire Terrier is a compact, toy-size t...
#
#                                     temperament popularity  min_height  \
# 0           Confident, Famously Funny, Fearless        148       22.86
# 1           Confident, Famously Funny, Fearless        148       22.86
# 2     Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 3     Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 4     Dignified, Profoundly Loyal, Aristocratic        113       63.50
# ...                                         ...        ...         ...
# 1242         Affectionate, Sprightly, Tomboyish         10       17.78
# 1243         Affectionate, Sprightly, Tomboyish         10       17.78
# 1244         Affectionate, Sprightly, Tomboyish         10       17.78
# 1245         Affectionate, Sprightly, Tomboyish         10       17.78
# 1246         Affectionate, Sprightly, Tomboyish         10       17.78
#
#       max_height  min_weight  max_weight  ...  grooming_frequency_value  \
# 0          29.21    3.175147    4.535924  ...                       0.6
# 1          29.21    3.175147    4.535924  ...                       0.6
# 2          68.58   22.679619   27.215542  ...                       0.8
# 3          68.58   22.679619   27.215542  ...                       0.8
# 4          68.58   22.679619   27.215542  ...                       0.8
# ...          ...         ...         ...  ...                       ...
# 1242       20.32    3.175147    3.175147  ...                       1.0
# 1243       20.32    3.175147    3.175147  ...                       1.0
# 1244       20.32    3.175147    3.175147  ...                       1.0
# 1245       20.32    3.175147    3.175147  ...                       1.0
# 1246       20.32    3.175147    3.175147  ...                       1.0
#
#       grooming_frequency_category shedding_value  shedding_category  \
# 0       2-3 Times a Week Brushing            0.6           Seasonal
# 1       2-3 Times a Week Brushing            0.6           Seasonal
# 2                  Daily Brushing            0.2         Infrequent
# 3                  Daily Brushing            0.2         Infrequent
# 4                  Daily Brushing            0.2         Infrequent
# ...                           ...            ...                ...
# 1242       Specialty/Professional            0.2         Infrequent
# 1243       Specialty/Professional            0.2         Infrequent
# 1244       Specialty/Professional            0.2         Infrequent
# 1245       Specialty/Professional            0.2         Infrequent
# 1246       Specialty/Professional            0.2         Infrequent
#
#      energy_level_value  energy_level_category trainability_value  \
# 0                   0.6       Regular Exercise                0.8
# 1                   0.6       Regular Exercise                0.8
# 2                   0.8              Energetic                0.2
# 3                   0.8              Energetic                0.2
# 4                   0.8              Energetic                0.2
# ...                 ...                    ...                ...
# 1242                0.6       Regular Exercise                0.2
# 1243                0.6       Regular Exercise                0.2
# 1244                0.6       Regular Exercise                0.2
# 1245                0.6       Regular Exercise                0.2
# 1246                0.6       Regular Exercise                0.2
#
#       trainability_category demeanor_value  demeanor_category
# 0             Easy Training            1.0           Outgoing
# 1             Easy Training            1.0           Outgoing
# 2           May be Stubborn            0.2         Aloof/Wary
# 3           May be Stubborn            0.2         Aloof/Wary
# 4           May be Stubborn            0.2         Aloof/Wary
# ...                     ...            ...                ...
# 1242        May be Stubborn            0.8           Friendly
# 1243        May be Stubborn            0.8           Friendly
# 1244        May be Stubborn            0.8           Friendly
# 1245        May be Stubborn            0.8           Friendly
# 1246        May be Stubborn            0.8           Friendly
#
# [1247 rows x 23 columns]

# %%
merged_df.to_csv("Disease.csv")

# %% [markdown]
# Scraping [from hillspet.com ](https://www.hillspet.com/dog-food)

# %%
import time
import random
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

CHROMEDRIVER_PATH = "C:/Users/bakht/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe" 

url = 'https://www.hillspet.com/dog-food'

chrome_options = Options()
chrome_options.add_argument('--headless')  
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--window-size=1920,1080')

driver = webdriver.Chrome(service=Service(CHROMEDRIVER_PATH), options=chrome_options)

data = []

def scrape_page(url):
    driver.get(url)
    time.sleep(5)  

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    product_blocks = soup.find_all('div', class_='grid-item-product')

    for block in product_blocks:
        # Title
        title_elem = block.find('h3', class_='product-title')
        title_text = title_elem.get_text(strip=True) if title_elem else 'N/A'

        # Description
        desc_elem = block.find('div', class_='product-description')
        description_text = desc_elem.get_text(strip=True) if desc_elem else 'N/A'

        # Rating
        rating_block = block.find('div', class_='bv_text')
        rating_text = rating_block.get_text(strip=True) if rating_block else 'N/A'

        # Link
        footer = block.find('div', class_='product-footer')
        link_tag = footer.find('a') if footer else None
        link = link_tag['href'] if link_tag else 'No link found'
        if not link.startswith('http'):
            link = 'https://www.hillspet.com' + link

        data.append({
            'Title': title_text,
            'Description': description_text,
            'Rating': rating_text,
            'Link': link
        })

scrape_page(url)

time.sleep(random.uniform(2, 5))

driver.quit()

df_links = pd.DataFrame(data)
df_links
df_links.to_csv("links_selenium.csv", index=False)

# %%
df_links
# Out:
#                                                  Title  \
# 0    Hill's Science Diet Perfect Digestion Small Bi...
# 1    Hill's Science Diet Adult Small Bites No Corn,...
# 2    Hill's Science Diet Adult 7+ Senior Vitality S...
# 3    Hill's Prescription Diet z/d Low Fat Hydrolyze...
# 4    Hill's Prescription Diet c/d Multicare Chicken...
# ..                                                 ...
# 192  Hill's Science Diet Adult Small & Mini Savory ...
# 193  Hill's  Grain Free Crunchy Naturals with Chick...
# 194  Hill's Science Diet Adult Perfect Digestion Ch...
# 195  Hill's Science Diet Puppy Small & Mini Savory ...
# 196  Hill's Prescription Diet c/d Multicare Chicken...
#
#                                            Description Rating  \
# 0    Science Diet's breakthrough nutrition supports...    0.0
# 1    Supports healthy immune system, digestion, lea...    4.0
# 2             Improves Everyday Ability to Get Up & Go    4.5
# 3    Nutrition specially formulated with hydrolyzed...    0.0
# 4                Support for your dog’s urinary health    4.4
# ..                                                 ...    ...
# 192  A delicious complement to the nutrition of Sci...    4.9
# 193                                                       5.0
# 194  Science Diet's breakthrough nutrition supports...    4.6
# 195  A delicious complement to the nutrition of Sci...    4.0
# 196              Support for your dog’s urinary health    5.0
#
#                                                   Link
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...
# ..                                                 ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...
# 193  https://www.hillspet.com/dog-food/grain-free-c...
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
# [197 rows x 4 columns]

# %% [markdown]
# First part

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

all_data = []

for i in df_links['Link']:
    try:
        response = requests.get(i)
        response.raise_for_status()  
        soup = BeautifulSoup(response.content, 'html.parser')

        product_title_elem = soup.find(class_='product-detail-title')
        product_title = product_title_elem.get_text(strip=True) if product_title_elem else 'N/A'

        product_description_elem = soup.find(class_='product-detail-description')
        product_description = product_description_elem.get_text(strip=True) if product_description_elem else 'N/A'

        # Extract list items
        list_items = soup.find_all(class_='list-item')
        list_data = {}
        for item in list_items:
            title_elem = item.find(class_='list-title')
            definition_elem = item.find(class_='list-definition')
            if title_elem and definition_elem:
                list_data[title_elem.get_text(strip=True)] = definition_elem.get_text(strip=True)

        # Extract text segments
        text_segments = soup.find_all(class_='text-segments no-icon false')
        segment_data = {}
        for segment in text_segments:
            bold_text_elem = segment.find(class_='segment bold')
            none_text_elem = segment.find(class_='segment none')
            bold_text = bold_text_elem.get_text(strip=True) if bold_text_elem else ''
            none_text = none_text_elem.get_text(strip=True) if none_text_elem else ''
            segment_data[bold_text] = none_text

        # Extract accordion titles and segment none
        accordion_titles = soup.find_all(class_='cmp-accordion__title')
        accordion_data = {}
        table_data = {}
        for accordion in accordion_titles:
            accordion_title = accordion.get_text(strip=True)
            segment_none_elem = accordion.find_next(class_='segment none')
            segment_none = segment_none_elem.get_text(strip=True) if segment_none_elem else ''
            accordion_data[accordion_title] = segment_none

            # Extract table data under "Average Nutrient & Caloric Content"
            if 'Average Nutrient & Caloric Content' in accordion_title:
                table = accordion.find_next('table')
                if table:
                    rows = table.find_all('tr')
                    for row in rows:
                        columns = row.find_all('td')
                        if len(columns) == 2:
                            column_name = columns[0].get_text(strip=True)
                            column_value = columns[1].get_text(strip=True)
                            table_data[column_name] = column_value

        data = {
            'URL': i,
            'Product Title': product_title,
            'Product Description': product_description,
            **list_data,
            **segment_data,
            **accordion_data,
            **table_data
        }

        all_data.append(data)

    except requests.exceptions.RequestException as e:
        print(f'Request failed for URL {i}: {e}')
    except AttributeError as e:
        print(f'AttributeError for URL {i}: {e}')
    except Exception as e:
        print(f'An error occurred for URL {i}: {e}')

    time.sleep(random.uniform(2, 5))  

df = pd.DataFrame(all_data)

def scrape_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status() 
        soup = BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f'Request failed for URL {url}: {e}')
    except Exception as e:
        print(f'An error occurred for URL {url}: {e}')

# %%
df
# Out:
#                                                    URL  \
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...
# ..                                                 ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...
# 193  https://www.hillspet.com/dog-food/grain-free-c...
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
#                                          Product Title  \
# 0    Perfect Digestion Small Bites Chicken, Brown R...
# 1    Adult Small Bites No Corn, Wheat, Soy Chicken ...
# 2    Adult 7+ Senior Vitality Small & Mini Chicken ...
# 3       z/d Low Fat Hydrolyzed Soy Recipe Wet Dog Food
# 4      c/d Multicare Chicken & Vegetable Stew Dog Food
# ..                                                 ...
# 192  Adult Small & Mini Savory Stew with Beef & Veg...
# 193  Grain Free Crunchy Naturals with Chicken & App...
# 194                                                N/A
# 195  Puppy Small & Mini Savory Stew with Chicken & ...
# 196              c/d Multicare Chicken Flavor Dog Food
#
#                                    Product Description Food Form  \
# 0    Science Diet's breakthrough nutrition supports...  Dry Food
# 1    Supports healthy immune system, digestion, lea...       dry
# 2             Improves Everyday Ability to Get Up & Go  Dry Food
# 3    Nutrition specially formulated with hydrolyzed...  Wet Food
# 4                Support for your dog’s urinary health      stew
# ..                                                 ...       ...
# 192  A delicious complement to the nutrition of Sci...      Tray
# 193                                                N/A    Treats
# 194                                                N/A       NaN
# 195  A delicious complement to the nutrition of Sci...  Wet Food
# 196              Support for your dog’s urinary health
#
#                                       Flavor            Sizes  \
# 0    Chicken, Brown Rice & Whole Oats Recipe           3.5 lb
# 1                Chicken & Brown Rice Recipe            15 lb
# 2                 Chicken Meal & Rice Recipe  3.5 lb, 12.5 lb
# 3                      Hydrolyzed Soy Recipe            13 oz
# 4                   Chicken & Vegetable Stew  12.5 oz, 5.5 oz
# ..                                       ...              ...
# 192       Savory Stew with Beef & Vegetables           3.5 oz
# 193                    with Chicken & Apples              8oz
# 194                                      NaN              NaN
# 195    Savory Stew with Chicken & Vegetables            3.5oz
# 196                           Chicken Flavor             13oz
#
#                                                         \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 192
# 193
# 194  Just like people, eating amounts vary from pet...
# 195
# 196
#
#                                        Caloric Content  \
# 0                           3620 kcal/kg 359 kcal/cup†
# 1                           3713 kcal/kg 389 kcal/cup†
# 2                           3651 kcal/kg 342 kcal/cup†
# 3
# 4    266 kcal / 12.5 oz (354 g) can\n117 kcal / 5.5...
# ..                                                 ...
# 192                        86 kcal / 3.5 oz (99g) tray
# 193
# 194                                                NaN
# 195                       90 kcal / 3.5 oz (99 g) tray
# 196
#
#                                            Ingredients  \
# 0    Chicken, Cracked Pearled Barley, Brown Rice, B...
# 1    Chicken, Brown Rice, Brewers Rice, Cracked Pea...
# 2    Chicken, Brewers Rice, Yellow Peas, Cracked Pe...
# 3    Water, corn starch, hydrolyzed soy protein, so...
# 4    Water, Chicken, Pork Liver, Carrots, Rice, Gre...
# ..                                                 ...
# 192  Water, Beef, Pork Liver, Brown Rice, Carrots, ...
# 193  Chicken, Yellow Peas, Potatoes, Potato Starch,...
# 194                                                NaN
# 195  Chicken Broth, Chicken, Pork Liver, Brown Rice...
# 196  Water, Beef By-Products, Chicken, Rice, Whole ...
#
#                                           Feeding Tips  ...  \
# 0    HELPFUL TIPSAdjust feeding amounts as necessar...  ...
# 1    HELPFUL TIPSAdjust feeding amounts as necessar...  ...
# 2    HELPFUL TIPSAdjust feeding amounts as necessar...  ...
# 3    Ask your veterinarian for specific feeding ins...  ...
# 4    Ask your veterinarian for specific feeding ins...  ...
# ..                                                 ...  ...
# 192  HELPFUL TIPSCover and refrigerate unused porti...  ...
# 193  We know that face is hard to resist, but feed ...  ...
# 194                                                NaN  ...
# 195  HELPFUL TIPSCover and refrigerate unused porti...  ...
# 196  Ask your veterinarian for specific feeding ins...  ...
#
#     Glutamine + Glutamate  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 192                   NaN
# 193                   NaN
# 194                   NaN
# 195                   NaN
# 196                   NaN
#
#     It looks like my pet’s food is currently out of stock. When will it be available again?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194  We understand how frustrating this pet food sh...
# 195                                                NaN
# 196                                                NaN
#
#     How can I know when my pet’s food will be back in stock?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194  With so many factors outside of our control, w...
# 195                                                NaN
# 196                                                NaN
#
#     How can I tell if my pet’s food formulation changed?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194  Hill’s is committed to delivering high-quality...
# 195                                                NaN
# 196                                                NaN
#
#                         How much should I feed my pet? Iron Copper Zinc  \
# 0                                                  NaN  NaN    NaN  NaN
# 1                                                  NaN  NaN    NaN  NaN
# 2                                                  NaN  NaN    NaN  NaN
# 3                                                  NaN  NaN    NaN  NaN
# 4                                                  NaN  NaN    NaN  NaN
# ..                                                 ...  ...    ...  ...
# 192                                                NaN  NaN    NaN  NaN
# 193                                                NaN  NaN    NaN  NaN
# 194  Just like people, eating amounts vary from pet...  NaN    NaN  NaN
# 195                                                NaN  NaN    NaN  NaN
# 196                                                NaN  NaN    NaN  NaN
#
#     Vitamin K Alpha-Linolenic Acid (ALA)
# 0         NaN                        NaN
# 1         NaN                        NaN
# 2         NaN                        NaN
# 3         NaN                        NaN
# 4         NaN                        NaN
# ..        ...                        ...
# 192       NaN                        NaN
# 193       NaN                        NaN
# 194       NaN                        NaN
# 195       NaN                        NaN
# 196       NaN                        NaN
#
# [197 rows x 53 columns]

# %%
df.to_csv("first.csv")

# %% [markdown]
# scrape some sections that didn’t work out the first time

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

all_data = []

for i in df_links['Link']:
    try:
        response = requests.get(i)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # === Title & Description ===
        title_elem = soup.find(class_='product-detail-title')
        description_elem = soup.find(class_='product-detail-description')
        product_title = title_elem.get_text(strip=True) if title_elem else 'N/A'
        product_description = description_elem.get_text(strip=True) if description_elem else 'N/A'

        # === Food Form / Flavor / Size ===
        food_form = flavor = size = 'N/A'
        segments = soup.find_all(class_='text-segments no-icon false')
        for segment in segments:
            label = segment.find(class_='segment bold')
            value = segment.find(class_='segment none')
            if label and value:
                label_text = label.get_text(strip=True)
                value_text = value.get_text(strip=True)
                if 'Food Form' in label_text:
                    food_form = value_text
                elif 'Flavor' in label_text:
                    flavor = value_text
                elif 'Size' in label_text:
                    size = value_text

        # === Accordion Fields ===
        accordion_items = soup.find_all(class_='cmp-accordion__item')
        accordion_data = {}
        nutrient_data = {}

        for item in accordion_items:
            title_elem = item.find(class_='cmp-accordion__title')
            if not title_elem:
                continue
            title_text = title_elem.get_text(strip=True)

            # if 'Key Features' in title_text:
            #     ul = item.find('ul')
            #     if ul:
            #         features = [li.get_text(strip=True) for li in ul.find_all('li')]
            #         accordion_data['Key Features'] = ' | '.join(features)
            #     continue
            if 'Key Features' in title_text:
                paragraph = item.find('p')
                ul = item.find('ul')
                features_text = ''

                if paragraph:
                    features_text += paragraph.get_text(strip=True) + ' '

                if ul:
                    bullet_items = [li.get_text(strip=True) for li in ul.find_all('li')]
                    features_text += ' '.join(bullet_items)

                accordion_data['Key Features'] = features_text.strip()
                continue

            segment = item.find(class_='segment none')
            text = segment.get_text(strip=True) if segment else ''

            if 'Ingredients' in title_text:
                accordion_data['Ingredients'] = text
            elif 'Feeding Tips' in title_text and 'Adult Maintenance' not in text:
                accordion_data['Feeding Tips'] = text
            elif 'Caloric Content' in title_text:
                accordion_data['Caloric Content'] = text

            # Nutrient Table
            # if 'Nutrient' in title_text:
            #     table = item.find('table')
            #     if table:
            #         for row in table.find_all('tr'):
            #             cols = row.find_all('td')
            #             if len(cols) == 2:
            #                 nutrient = cols[0].get_text(strip=True)
            #                 value = cols[1].get_text(strip=True)
            #                 nutrient_data[f'Nutrient - {nutrient}'] = value
            if 'Nutrient' in title_text or 'Caloric' in title_text:
                table = item.find('table')
                if table:
                    rows = table.find_all('tr')
                    for row in rows:
                        cells = row.find_all('td')
                        if len(cells) == 2:
                            key = cells[0].get_text(strip=True)
                            value = cells[1].get_text(strip=True)
                            if key.lower() == "nutrient" or "dry matter" in value.lower():
                                continue
                            nutrient_data[f'{key}'] = value

        # === Recommended (Outside Accordion) ===
        recommended_for  = 'N/A'
        segments_bold = soup.find_all(class_='segment bold')
        for seg in segments_bold:
            text = seg.get_text(strip=True)
            if 'Recommended for' in text:
                sibling = seg.find_next_sibling('div', class_='segment none')
                if sibling:
                    recommended_for = sibling.get_text(strip=True)

        # === Final Merge ===
        data = {
            'URL': i,
            'Product Title': product_title,
            'Product Description': product_description,
            'Food Form': food_form,
            'Flavor': flavor,
            'Size': size,
            'Recommended For': recommended_for,
            **accordion_data,
            **nutrient_data
        }

        all_data.append(data)

    except Exception as e:
        print(f"[ERROR] {i}: {e}")

    time.sleep(random.uniform(2, 4))

# Save to DataFrame
df1 = pd.DataFrame(all_data)
df1
# Out:
#                                                    URL  \
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...
# ..                                                 ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...
# 193  https://www.hillspet.com/dog-food/grain-free-c...
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
#                                          Product Title  \
# 0    Perfect Digestion Small Bites Chicken, Brown R...
# 1    Adult Small Bites No Corn, Wheat, Soy Chicken ...
# 2    Adult 7+ Senior Vitality Small & Mini Chicken ...
# 3       z/d Low Fat Hydrolyzed Soy Recipe Wet Dog Food
# 4      c/d Multicare Chicken & Vegetable Stew Dog Food
# ..                                                 ...
# 192  Adult Small & Mini Savory Stew with Beef & Veg...
# 193  Grain Free Crunchy Naturals with Chicken & App...
# 194                                                N/A
# 195  Puppy Small & Mini Savory Stew with Chicken & ...
# 196              c/d Multicare Chicken Flavor Dog Food
#
#                                    Product Description Food Form Flavor Size  \
# 0    Science Diet's breakthrough nutrition supports...       N/A    N/A  N/A
# 1    Supports healthy immune system, digestion, lea...       N/A    N/A  N/A
# 2             Improves Everyday Ability to Get Up & Go       N/A    N/A  N/A
# 3    Nutrition specially formulated with hydrolyzed...       N/A    N/A  N/A
# 4                Support for your dog’s urinary health       N/A    N/A  N/A
# ..                                                 ...       ...    ...  ...
# 192  A delicious complement to the nutrition of Sci...       N/A    N/A  N/A
# 193                                                N/A       N/A    N/A  N/A
# 194                                                N/A       N/A    N/A  N/A
# 195  A delicious complement to the nutrition of Sci...       N/A    N/A  N/A
# 196              Support for your dog’s urinary health       N/A    N/A  N/A
#
#                                        Recommended For  \
# 0    Adult dogs 1 - 6 years to help keep their dige...
# 1                       Adult dogs 1 - 6 years of age.
# 2                           Adult dogs 7+ years of age
# 3                                           Adult Dogs
# 4                                           Adult Dogs
# ..                                                 ...
# 192                     Adult dogs 1 - 6 years of age.
# 193  Normally active puppy (9+ weeks old), adult & ...
# 194                                                N/A
# 195  Puppies up to 1 year old and pregnant or nursi...
# 196                                         Adult Dogs
#
#                                            Ingredients  \
# 0    Chicken, Cracked Pearled Barley, Brown Rice, B...
# 1    Chicken, Brown Rice, Brewers Rice, Cracked Pea...
# 2    Chicken, Brewers Rice, Yellow Peas, Cracked Pe...
# 3    Water, corn starch, hydrolyzed soy protein, so...
# 4    Water, Chicken, Pork Liver, Carrots, Rice, Gre...
# ..                                                 ...
# 192  Water, Beef, Pork Liver, Brown Rice, Carrots, ...
# 193  Chicken, Yellow Peas, Potatoes, Potato Starch,...
# 194                                                NaN
# 195  Chicken Broth, Chicken, Pork Liver, Brown Rice...
# 196  Water, Beef By-Products, Chicken, Rice, Whole ...
#
#                                           Feeding Tips  \
# 0    HELPFUL TIPSAdjust feeding amounts as necessar...
# 1    HELPFUL TIPSAdjust feeding amounts as necessar...
# 2    HELPFUL TIPSAdjust feeding amounts as necessar...
# 3    Ask your veterinarian for specific feeding ins...
# 4    Ask your veterinarian for specific feeding ins...
# ..                                                 ...
# 192  HELPFUL TIPSCover and refrigerate unused porti...
# 193  We know that face is hard to resist, but feed ...
# 194                                                NaN
# 195  HELPFUL TIPSCover and refrigerate unused porti...
# 196  Ask your veterinarian for specific feeding ins...
#
#                                           Key Features  ... Linoleic Acid  \
# 0    Prebiotics are nutrients that feed the billion...  ...           NaN
# 1    Hill's Science Diet Adult Small Bites No Corn,...  ...           NaN
# 2    Hill's Science Diet Youthful Vitality Small & ...  ...           NaN
# 3    Dogs with recurrent gastrointestinal upset may...  ...           NaN
# 4    Bladder stones are collections of mineral crys...  ...           NaN
# ..                                                 ...  ...           ...
# 192  Hill's Science Diet Adult Small Paws Savory St...  ...           NaN
# 193  Hill's Grain Free Crunchy Naturals with Chicke...  ...           NaN
# 194                                                NaN  ...           NaN
# 195  Hill's Science Diet Puppy Small & Mini Savory ...  ...           NaN
# 196  Bladder stones are collections of mineral crys...  ...           NaN
#
#     {{consumer_nutrientTable_name_label}} Chloride BCAA Total  \
# 0                                     NaN      NaN        NaN
# 1                                     NaN      NaN        NaN
# 2                                     NaN      NaN        NaN
# 3                                     NaN      NaN        NaN
# 4                                     NaN      NaN        NaN
# ..                                    ...      ...        ...
# 192                                   NaN      NaN        NaN
# 193                                   NaN      NaN        NaN
# 194                                   NaN      NaN        NaN
# 195                                   NaN      NaN        NaN
# 196                                   NaN      NaN        NaN
#
#     Glutamine + Glutamate Iron Copper Zinc Vitamin K  \
# 0                     NaN  NaN    NaN  NaN       NaN
# 1                     NaN  NaN    NaN  NaN       NaN
# 2                     NaN  NaN    NaN  NaN       NaN
# 3                     NaN  NaN    NaN  NaN       NaN
# 4                     NaN  NaN    NaN  NaN       NaN
# ..                    ...  ...    ...  ...       ...
# 192                   NaN  NaN    NaN  NaN       NaN
# 193                   NaN  NaN    NaN  NaN       NaN
# 194                   NaN  NaN    NaN  NaN       NaN
# 195                   NaN  NaN    NaN  NaN       NaN
# 196                   NaN  NaN    NaN  NaN       NaN
#
#     Alpha-Linolenic Acid (ALA)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 192                        NaN
# 193                        NaN
# 194                        NaN
# 195                        NaN
# 196                        NaN
#
# [197 rows x 46 columns]

# %%
df1.to_csv("hillspet_full_scrape.csv", index=False)

# %%
columns_to_remove = ["Food Form", "Flavor", "Size", "{{consumer_nutrientTable_name_label}}"]
df_cleaned = df1.drop(columns=[col for col in columns_to_remove if col in df1.columns])

# %%
df_cleaned
# Out:
#                                                    URL  \
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...
# ..                                                 ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...
# 193  https://www.hillspet.com/dog-food/grain-free-c...
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
#                                          Product Title  \
# 0    Perfect Digestion Small Bites Chicken, Brown R...
# 1    Adult Small Bites No Corn, Wheat, Soy Chicken ...
# 2    Adult 7+ Senior Vitality Small & Mini Chicken ...
# 3       z/d Low Fat Hydrolyzed Soy Recipe Wet Dog Food
# 4      c/d Multicare Chicken & Vegetable Stew Dog Food
# ..                                                 ...
# 192  Adult Small & Mini Savory Stew with Beef & Veg...
# 193  Grain Free Crunchy Naturals with Chicken & App...
# 194                                                N/A
# 195  Puppy Small & Mini Savory Stew with Chicken & ...
# 196              c/d Multicare Chicken Flavor Dog Food
#
#                                    Product Description  \
# 0    Science Diet's breakthrough nutrition supports...
# 1    Supports healthy immune system, digestion, lea...
# 2             Improves Everyday Ability to Get Up & Go
# 3    Nutrition specially formulated with hydrolyzed...
# 4                Support for your dog’s urinary health
# ..                                                 ...
# 192  A delicious complement to the nutrition of Sci...
# 193                                                N/A
# 194                                                N/A
# 195  A delicious complement to the nutrition of Sci...
# 196              Support for your dog’s urinary health
#
#                                        Recommended For  \
# 0    Adult dogs 1 - 6 years to help keep their dige...
# 1                       Adult dogs 1 - 6 years of age.
# 2                           Adult dogs 7+ years of age
# 3                                           Adult Dogs
# 4                                           Adult Dogs
# ..                                                 ...
# 192                     Adult dogs 1 - 6 years of age.
# 193  Normally active puppy (9+ weeks old), adult & ...
# 194                                                N/A
# 195  Puppies up to 1 year old and pregnant or nursi...
# 196                                         Adult Dogs
#
#                                            Ingredients  \
# 0    Chicken, Cracked Pearled Barley, Brown Rice, B...
# 1    Chicken, Brown Rice, Brewers Rice, Cracked Pea...
# 2    Chicken, Brewers Rice, Yellow Peas, Cracked Pe...
# 3    Water, corn starch, hydrolyzed soy protein, so...
# 4    Water, Chicken, Pork Liver, Carrots, Rice, Gre...
# ..                                                 ...
# 192  Water, Beef, Pork Liver, Brown Rice, Carrots, ...
# 193  Chicken, Yellow Peas, Potatoes, Potato Starch,...
# 194                                                NaN
# 195  Chicken Broth, Chicken, Pork Liver, Brown Rice...
# 196  Water, Beef By-Products, Chicken, Rice, Whole ...
#
#                                           Feeding Tips  \
# 0    HELPFUL TIPSAdjust feeding amounts as necessar...
# 1    HELPFUL TIPSAdjust feeding amounts as necessar...
# 2    HELPFUL TIPSAdjust feeding amounts as necessar...
# 3    Ask your veterinarian for specific feeding ins...
# 4    Ask your veterinarian for specific feeding ins...
# ..                                                 ...
# 192  HELPFUL TIPSCover and refrigerate unused porti...
# 193  We know that face is hard to resist, but feed ...
# 194                                                NaN
# 195  HELPFUL TIPSCover and refrigerate unused porti...
# 196  Ask your veterinarian for specific feeding ins...
#
#                                           Key Features  \
# 0    Prebiotics are nutrients that feed the billion...
# 1    Hill's Science Diet Adult Small Bites No Corn,...
# 2    Hill's Science Diet Youthful Vitality Small & ...
# 3    Dogs with recurrent gastrointestinal upset may...
# 4    Bladder stones are collections of mineral crys...
# ..                                                 ...
# 192  Hill's Science Diet Adult Small Paws Savory St...
# 193  Hill's Grain Free Crunchy Naturals with Chicke...
# 194                                                NaN
# 195  Hill's Science Diet Puppy Small & Mini Savory ...
# 196  Bladder stones are collections of mineral crys...
#
#                                        Caloric Content Protein     Fat  ...  \
# 0                           3620 kcal/kg 359 kcal/cup†    25 %  14.5 %  ...
# 1                           3713 kcal/kg 389 kcal/cup†  23.6 %  16.4 %  ...
# 2                           3651 kcal/kg 342 kcal/cup†  22.4 %  14.6 %  ...
# 3                                                       29.9 %   9.4 %  ...
# 4    266 kcal / 12.5 oz (354 g) can\n117 kcal / 5.5...  22.8 %  18.3 %  ...
# ..                                                 ...     ...     ...  ...
# 192                        86 kcal / 3.5 oz (99g) tray  27.1 %  21.3 %  ...
# 193                                                     16.6 %   9.6 %  ...
# 194                                                NaN     NaN     NaN  ...
# 195                       90 kcal / 3.5 oz (99 g) tray  30.7 %  18.1 %  ...
# 196                                                     24.3 %  16.6 %  ...
#
#     Taurine Linoleic Acid Chloride BCAA Total Glutamine + Glutamate Iron  \
# 0       NaN           NaN      NaN        NaN                   NaN  NaN
# 1       NaN           NaN      NaN        NaN                   NaN  NaN
# 2       NaN           NaN      NaN        NaN                   NaN  NaN
# 3       NaN           NaN      NaN        NaN                   NaN  NaN
# 4       NaN           NaN      NaN        NaN                   NaN  NaN
# ..      ...           ...      ...        ...                   ...  ...
# 192     NaN           NaN      NaN        NaN                   NaN  NaN
# 193     NaN           NaN      NaN        NaN                   NaN  NaN
# 194     NaN           NaN      NaN        NaN                   NaN  NaN
# 195     NaN           NaN      NaN        NaN                   NaN  NaN
# 196     NaN           NaN      NaN        NaN                   NaN  NaN
#
#     Copper Zinc Vitamin K Alpha-Linolenic Acid (ALA)
# 0      NaN  NaN       NaN                        NaN
# 1      NaN  NaN       NaN                        NaN
# 2      NaN  NaN       NaN                        NaN
# 3      NaN  NaN       NaN                        NaN
# 4      NaN  NaN       NaN                        NaN
# ..     ...  ...       ...                        ...
# 192    NaN  NaN       NaN                        NaN
# 193    NaN  NaN       NaN                        NaN
# 194    NaN  NaN       NaN                        NaN
# 195    NaN  NaN       NaN                        NaN
# 196    NaN  NaN       NaN                        NaN
#
# [197 rows x 42 columns]

# %%
df_cleaned.to_csv("second.csv", index=False)

# %% [markdown]
# Take the necessary columns from the first file and add them to the second file

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['URL', 'Product Title', 'Product Description', 'Food Form', 'Flavor', 'Sizes', '', 'Caloric Content', 'Ingredients', 'Feeding Tips', 'Key Features', 'Average Nutrient & Caloric Content', 'Nutrient', 'Protein', 'Fat', 'Carbohydrate / NFE', 'Crude Fiber', 'Calcium', 'Phosphorus', 'Potassium', 'Sodium', 'Magnesium', 'Vitamin C', 'Vitamin E', 'Total Omega-3 FA', 'Total Omega-6 FA', 'Ash', 'Vitamin A', 'Vitamin D', 'Beta-Carotene', 'EPA', 'Carnitine', 'Adult Maintenance', 'DHA', 'Glucosamine', 'Chondroitin Sulfate', 'Total Dietary Fiber', 'Lysine', 'Taurine', 'Linoleic Acid', '{{consumer_nutrientTable_name_label}}', 'Chloride', 'BCAA Total', 'Glutamine + Glutamate', 'It looks like my pet’s food is currently out of stock. When will it be available again?', 'How can I know when my pet’s food will be back in stock?', 'How can I tell if my pet’s food formulation changed?', 'How much should I feed my pet?', 'Iron', 'Copper', 'Zinc', 'Vitamin K', 'Alpha-Linolenic Acid (ALA)']

# %%
df_first = df[['URL', 'Food Form', 'Flavor', 'Sizes']]

# %%
df_first
# Out:
#                                                    URL Food Form  \
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...  Dry Food
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...       dry
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...  Dry Food
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...  Wet Food
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...      stew
# ..                                                 ...       ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...      Tray
# 193  https://www.hillspet.com/dog-food/grain-free-c...    Treats
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...       NaN
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...  Wet Food
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
#                                       Flavor            Sizes
# 0    Chicken, Brown Rice & Whole Oats Recipe           3.5 lb
# 1                Chicken & Brown Rice Recipe            15 lb
# 2                 Chicken Meal & Rice Recipe  3.5 lb, 12.5 lb
# 3                      Hydrolyzed Soy Recipe            13 oz
# 4                   Chicken & Vegetable Stew  12.5 oz, 5.5 oz
# ..                                       ...              ...
# 192       Savory Stew with Beef & Vegetables           3.5 oz
# 193                    with Chicken & Apples              8oz
# 194                                      NaN              NaN
# 195    Savory Stew with Chicken & Vegetables            3.5oz
# 196                           Chicken Flavor             13oz
#
# [197 rows x 4 columns]

# %%
df_merged = pd.merge(df_cleaned, df_first, on='URL', how='left')

cols = df_merged.columns.tolist()
insert_after = 'Product Description'
insert_at = cols.index(insert_after) + 1

for col in ['Food Form', 'Flavor', 'Sizes']:
    if col in cols:
        cols.remove(col)
        
for col in reversed(['Food Form','Flavor', 'Sizes']):
    cols.insert(insert_at, col)

df_reorder = df_merged[cols]

df_reorder.to_csv("final1.csv", index=False)

# %%
df_reorder
# Out:
#                                                    URL  \
# 0    https://www.hillspet.com/dog-food/sd-canine-ad...
# 1    https://www.hillspet.com/dog-food/sd-canine-ad...
# 2    https://www.hillspet.com/dog-food/sd-canine-ad...
# 3    https://www.hillspet.com/dog-food/pd-canine-zd...
# 4    https://www.hillspet.com/dog-food/pd-cd-multic...
# ..                                                 ...
# 192  https://www.hillspet.com/dog-food/sd-adult-sma...
# 193  https://www.hillspet.com/dog-food/grain-free-c...
# 194  https://www.hillspet.com/dog-food/sd-canine-ad...
# 195  https://www.hillspet.com/dog-food/sd-canine-pu...
# 196  https://www.hillspet.com/dog-food/pd-cd-multic...
#
#                                          Product Title  \
# 0    Perfect Digestion Small Bites Chicken, Brown R...
# 1    Adult Small Bites No Corn, Wheat, Soy Chicken ...
# 2    Adult 7+ Senior Vitality Small & Mini Chicken ...
# 3       z/d Low Fat Hydrolyzed Soy Recipe Wet Dog Food
# 4      c/d Multicare Chicken & Vegetable Stew Dog Food
# ..                                                 ...
# 192  Adult Small & Mini Savory Stew with Beef & Veg...
# 193  Grain Free Crunchy Naturals with Chicken & App...
# 194                                                N/A
# 195  Puppy Small & Mini Savory Stew with Chicken & ...
# 196              c/d Multicare Chicken Flavor Dog Food
#
#                                    Product Description Food Form  \
# 0    Science Diet's breakthrough nutrition supports...  Dry Food
# 1    Supports healthy immune system, digestion, lea...       dry
# 2             Improves Everyday Ability to Get Up & Go  Dry Food
# 3    Nutrition specially formulated with hydrolyzed...  Wet Food
# 4                Support for your dog’s urinary health      stew
# ..                                                 ...       ...
# 192  A delicious complement to the nutrition of Sci...      Tray
# 193                                                N/A    Treats
# 194                                                N/A       NaN
# 195  A delicious complement to the nutrition of Sci...  Wet Food
# 196              Support for your dog’s urinary health
#
#                                       Flavor            Sizes  \
# 0    Chicken, Brown Rice & Whole Oats Recipe           3.5 lb
# 1                Chicken & Brown Rice Recipe            15 lb
# 2                 Chicken Meal & Rice Recipe  3.5 lb, 12.5 lb
# 3                      Hydrolyzed Soy Recipe            13 oz
# 4                   Chicken & Vegetable Stew  12.5 oz, 5.5 oz
# ..                                       ...              ...
# 192       Savory Stew with Beef & Vegetables           3.5 oz
# 193                    with Chicken & Apples              8oz
# 194                                      NaN              NaN
# 195    Savory Stew with Chicken & Vegetables            3.5oz
# 196                           Chicken Flavor             13oz
#
#                                        Recommended For  \
# 0    Adult dogs 1 - 6 years to help keep their dige...
# 1                       Adult dogs 1 - 6 years of age.
# 2                           Adult dogs 7+ years of age
# 3                                           Adult Dogs
# 4                                           Adult Dogs
# ..                                                 ...
# 192                     Adult dogs 1 - 6 years of age.
# 193  Normally active puppy (9+ weeks old), adult & ...
# 194                                                N/A
# 195  Puppies up to 1 year old and pregnant or nursi...
# 196                                         Adult Dogs
#
#                                            Ingredients  \
# 0    Chicken, Cracked Pearled Barley, Brown Rice, B...
# 1    Chicken, Brown Rice, Brewers Rice, Cracked Pea...
# 2    Chicken, Brewers Rice, Yellow Peas, Cracked Pe...
# 3    Water, corn starch, hydrolyzed soy protein, so...
# 4    Water, Chicken, Pork Liver, Carrots, Rice, Gre...
# ..                                                 ...
# 192  Water, Beef, Pork Liver, Brown Rice, Carrots, ...
# 193  Chicken, Yellow Peas, Potatoes, Potato Starch,...
# 194                                                NaN
# 195  Chicken Broth, Chicken, Pork Liver, Brown Rice...
# 196  Water, Beef By-Products, Chicken, Rice, Whole ...
#
#                                           Feeding Tips  \
# 0    HELPFUL TIPSAdjust feeding amounts as necessar...
# 1    HELPFUL TIPSAdjust feeding amounts as necessar...
# 2    HELPFUL TIPSAdjust feeding amounts as necessar...
# 3    Ask your veterinarian for specific feeding ins...
# 4    Ask your veterinarian for specific feeding ins...
# ..                                                 ...
# 192  HELPFUL TIPSCover and refrigerate unused porti...
# 193  We know that face is hard to resist, but feed ...
# 194                                                NaN
# 195  HELPFUL TIPSCover and refrigerate unused porti...
# 196  Ask your veterinarian for specific feeding ins...
#
#                                           Key Features  ... Taurine  \
# 0    Prebiotics are nutrients that feed the billion...  ...     NaN
# 1    Hill's Science Diet Adult Small Bites No Corn,...  ...     NaN
# 2    Hill's Science Diet Youthful Vitality Small & ...  ...     NaN
# 3    Dogs with recurrent gastrointestinal upset may...  ...     NaN
# 4    Bladder stones are collections of mineral crys...  ...     NaN
# ..                                                 ...  ...     ...
# 192  Hill's Science Diet Adult Small Paws Savory St...  ...     NaN
# 193  Hill's Grain Free Crunchy Naturals with Chicke...  ...     NaN
# 194                                                NaN  ...     NaN
# 195  Hill's Science Diet Puppy Small & Mini Savory ...  ...     NaN
# 196  Bladder stones are collections of mineral crys...  ...     NaN
#
#     Linoleic Acid Chloride BCAA Total Glutamine + Glutamate Iron Copper Zinc  \
# 0             NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 1             NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 2             NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 3             NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 4             NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# ..            ...      ...        ...                   ...  ...    ...  ...
# 192           NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 193           NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 194           NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 195           NaN      NaN        NaN                   NaN  NaN    NaN  NaN
# 196           NaN      NaN        NaN                   NaN  NaN    NaN  NaN
#
#     Vitamin K Alpha-Linolenic Acid (ALA)
# 0         NaN                        NaN
# 1         NaN                        NaN
# 2         NaN                        NaN
# 3         NaN                        NaN
# 4         NaN                        NaN
# ..        ...                        ...
# 192       NaN                        NaN
# 193       NaN                        NaN
# 194       NaN                        NaN
# 195       NaN                        NaN
# 196       NaN                        NaN
#
# [197 rows x 45 columns]

# %%
if "Feeding Tips" in df_reorder.columns:
    df_reorder["Feeding Tips"] = df_reorder["Feeding Tips"].str.replace(
        r"(?i)^helpful tips[:\s]*", "", regex=True
    )
df_reorder.to_csv("final1.csv", index=False)

# %%
df_reorder.columns = df_reorder.columns.str.strip().str.lower()
df_reorder.to_csv("final1.csv", index=False)

# %% [markdown]
# Scraping [from hillspet.co.uk](https://www.hillspet.co.uk/products/dog-food)

# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import pandas as pd

# url = 'https://www.hillspet.com/dog-food'
url = 'https://www.hillspet.co.uk/products/dog-food'

# List to store the scraped data
data = []

# Function to scrape a single page
def scrape_page(url):
    # Send a GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all elements with the specified classes
        product_titles = soup.find_all(class_='articleList-title')
        product_footers = soup.find_all(class_='articleList-description')

        # Extract and store the data from each element
        for title, footer in zip(product_titles, product_footers):
            title_text = title.get_text(strip=True)
            relative_link = footer.find('a')['href'] if footer.find('a') else ''
            link = f"https://www.hillspet.co.uk{relative_link}" if relative_link else 'No link found'

            # Append the data to the list
            data.append({
                'Title': title_text,
                'Link': link
            })
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

# Scrape the initial page
scrape_page(url)

time.sleep(random.uniform(2, 5))  

# Create a DataFrame from the collected data
df_links = pd.DataFrame(data)
df_links.to_csv("UK_links.csv", index=False)


df_links
# Out:
#                                                  Title  \
# 0    Hill's Prescription Dietk/d Kidney Care Wet Do...
# 1    Hill's Prescription Dietl/d Wet Dog Food Original
# 2    Hill's Science PlanAdult Large Breed Dry Dog F...
# 3    Hill's Science PlanMedium Mature Adult 7+ Dog ...
# 4            Hill's Prescription Diett/d Mini Dog Food
# ..                                                 ...
# 130  Hill's Science PlanPerfect Digestion Adult Lar...
# 131  Hill's Science PlanPuppy Wet Dog Food with Chi...
# 132  Hill's Prescription DietDerm Complete Puppy Dr...
# 133  Hill's Vet EssentialsMulti-BenefitAdult Wet Do...
# 134  Hill's Prescription Dietz/d Food Sensitivities...
#
#                                                   Link
# 0    https://www.hillspet.co.uk/dog-food/pd-canine-...
# 1    https://www.hillspet.co.uk/dog-food/pd-canine-...
# 2    https://www.hillspet.co.uk/dog-food/sp-canine-...
# 3    https://www.hillspet.co.uk/dog-food/sp-canine-...
# 4    https://www.hillspet.co.uk/dog-food/pd-canine-...
# ..                                                 ...
# 130  https://www.hillspet.co.uk/dog-food/sp-canine-...
# 131  https://www.hillspet.co.uk/dog-food/sp-canine-...
# 132  https://www.hillspet.co.uk/dog-food/pd-canine-...
# 133  https://www.hillspet.co.uk/dog-food/ve-canine-...
# 134  https://www.hillspet.co.uk/dog-food/pd-canine-...
#
# [135 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

df_links = pd.read_csv("UK_links.csv")  # 135 product URLs

all_data = []

for url in df_links['Link']:
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # ----------- Title & Description -----------
        title_elem = soup.select_one("div.productAwareRichText h1")
        product_title = title_elem.get_text(strip=True) if title_elem else "N/A"

        desc_elem = soup.select_one("div.productAwareRichText p")
        product_description = desc_elem.get_text(strip=True) if desc_elem else "N/A"


        # ----------- Description Attributes (Need/Preference, Flavour, etc.) -----------
        attributes = {}
        desc_blocks = soup.find_all("div", class_="pdp-2019-description-row")

        for block in desc_blocks:
            paragraph = block.find("div", class_="paragraphSystem content")
            if paragraph:
                ps = paragraph.find_all("p")
                if len(ps) >= 2:
                    key = ps[0].get_text(strip=True).rstrip(":")
                    value = ps[1].get_text(strip=True)
                    if key and value:
                        attributes[key] = value

        # ----------- Accordion-like Sections: Key Benefits, Ingredients -----------
        # accordion_data = {}
        # for h3 in soup.find_all("h3", class_="accordion-title component"):
        #     section_title = h3.get_text(strip=True)
        #     content_div = h3.find_parent("li").find_next("id", class_="accordion-content-wrapper")
        #     if content_div:
        #         accordion_data[section_title] = content_div.get_text(strip=True)



        # ----------- Combine All Info -----------
        data = {
            "URL": url,
            "Product Title": product_title,
            "Product Description": product_description,
            **attributes,        # Flavour, Sizes, etc.
        }

        all_data.append(data)
        print(f" Scraped: {product_title}")

    except Exception as e:
        print(f" Failed on {url}: {e}")
    
    time.sleep(random.uniform(1.5, 3.0))

# ----------- Save to CSV -----------
df_UK1 = pd.DataFrame(all_data)
df_UK1.to_csv("UK_first.csv", index=False)
print(" Scraping complete. Data saved to UK_first.csv")
# Out:
#  Scraped: k/d Kidney Care Wet Dog Food Original Can
#  Scraped: l/d Wet Dog Food Original
#  Scraped: Adult Large Breed Dry Dog Food with Lamb & Rice
#  Scraped: Medium Mature Adult 7+ Dog Food with Chicken Dry Bag
#  Scraped: t/d Mini Dog Food
#  Scraped: Medium Puppy Food
#  Scraped: d/d Food Sensitivities Dry Dog Food with Duck & Rice Bag
#  Scraped: Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Mature Adult Medium Dog Food
#  Scraped: Light Adult Wet Dog Food with Chicken
#  Scraped: b/d Brain Ageing Care Dry Dog Food with Chicken Bag
#  Scraped: u/d Dry Dog Food Original
#  Scraped: t/d Dog Food
#  Scraped: Oral Care Adult Dry Dog Food with Chicken
#  Scraped: l/d Dry Dog Food Original
#  Scraped: k/d Dog Food
#  Scraped: Light Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Puppy Medium Breed Dry Dog Food with Lamb & Rice
#  Scraped: Adult Wet Dog Food with Turkey
#  Scraped: Adult Medium Breed Dry Dog Food with Lamb & Rice
#  Scraped: Puppy Large Breed Dry Dog Food with Chicken
#  Scraped: Healthy Weight Dog Treats
#  Scraped: Hypoallergenic Dog Treats
#  Scraped: c/d Multicare Dry Dog Food with Chicken Bag
#  Scraped: Perfect Weight Adult Small & Mini Breed Dog Mousse with Turkey
#  Scraped: Mature Adult Multipack Wet Dog Food with Chicken & Beef
#  Scraped: Puppy Multipack Wet Dog Food with Chicken & Beef
#  Scraped: i/d Stress Mini Dog Food
#  Scraped: Adult Multipack Wet Dog Food with Chicken, Turkey & Beef
#  Scraped: Multi-Benefit + Senior Health Mature Adult Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult Wet Dog Food
#  Scraped: Multi-Benefit Puppy Wet Food
#  Scraped: Perfect Digestion Adult Small & Mini Breed Dog Mousse with Turkey
#  Scraped: Small & Mini Breed Adult Dog Mousse with Chicken
#  Scraped: j/d Wet Dog Food with Chicken
#  Scraped: k/d + Mobility Dog Food
#  Scraped: i/d Stress Wet Dog Food with Chicken
#  Scraped: Puppy Small & Mini Breed Dry Food with Chicken
#  Scraped: Gastrointestinal Biome Mini Dry Dog Food with Chicken Bag
#  Scraped: Senior Vitality Mature Adult Small & Mini Breed Dry Dog Food with Chicken & Rice
#  Scraped: Perfect Digestion Puppy Large Breed Dry Dog Food Chicken & Brown Rice
#  Scraped: Perfect Digestion Puppy Small & Mini Dry Dog Food Chicken & Brown Rice
#  Scraped: Hypoallergenic Adult Large Breed Dry Dog Food with Salmon
#  Scraped: Perfect Digestion Puppy Medium Breed Dry Food Chicken & Brown Rice
#  Scraped: Metabolic + Mobility Weight Management Dog Food
#  Scraped: Hypoallergenic Adult Medium Breed Dry Dog Food with Salmon
#  Scraped: Hypoallergenic Adult Small & Mini Breed Dry Dog Food with Salmon
#  Scraped: On-Care Stew for Dogs
#  Scraped: Gastrointestinal Biome Wet Dog Food with Chicken
#  Scraped: On-Care Dry Dog Food
#  Scraped: Derm Complete Dry Dog Food Original
#  Scraped: Metabolic Weight Management Dog Food
#  Scraped: Derm Complete Skin Care & Food Sensitivities Wet Dog Food Original Can
#  Scraped: Large Breed Mature Adult Dog Food
#  Scraped: Metabolic + Mobility Mini Dog Food
#  Scraped: Perfect Weight & Active Mobility Adult Large Dry Dog Food Chicken
#  Scraped: Perfect Weight & Active Mobility Small & Mini Dry Dog Food Chicken
#  Scraped: Perfect Digestion Adult Small & Mini Dry Dog Food Chicken & Brown Rice
#  Scraped: Multi-Benefit Adult Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Large Breed Dry Dog Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Large Breed Dry Dog Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Small & Mini Dry Dog Food
#  Scraped: a/d Dog/Cat Food
#  Scraped: Perfect Digestion Medium Adult 1+ Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Small & Mini Dry Dog Food
#  Scraped: Perfect Digestion Adult Dog Food
#  Scraped: Derm Complete Mini Dog Food
#  Scraped: Multi-Benefit Adult Medium Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Medium Dry Dog Food
#  Scraped: Multi-Benefit Puppy Small & Mini Dry Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Medium Dry Dog Food with Chicken Bag
#  Scraped: Gastrointestinal Biome Stew for Dogs with Chicken & added Carrots Can
#  Scraped: Perfect Weight & Active Mobility Adult Medium Dry Dog Food Chicken
#  Scraped: k/d Early Stage Dog Food
#  Scraped: Gastrointestinal Biome Dry Dog Food with Chicken Bag
#  Scraped: Metabolic Stew for Dog with Chicken & Vegetables
#  Scraped: i/d Digestive Care Dog Food
#  Scraped: k/d Stew for Dogs
#  Scraped: Light Mature Adult Medium Dry Dog Food with Chicken Bag
#  Scraped: i/d Stress Mini Stew for Dogs
#  Scraped: d/d Food Sensitivities Wet Dog Food Duck Can
#  Scraped: Sensitive Stomach & Skin Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Multi-Benefit Puppy Large Breed Dry Food
#  Scraped: i/d Low Fat Digestive Care Dog Food
#  Scraped: c/d Multicare Urinary Care Stew for Dog Food with Chicken & added Vegetables Can
#  Scraped: Metabolic Mini Dog Food
#  Scraped: Adult Small & Mini Breed Dry Dog Food with Lamb & Rice
#  Scraped: z/d Food Sensitivities Dog Wet Food Original Can
#  Scraped: Healthy Mobility Adult Large Breed Adult Dry Dog Food with Chicken
#  Scraped: Mature Adult Wet Dog Food with Chicken
#  Scraped: Metabolic Dry Dog Food with Chicken
#  Scraped: Metabolic + Mobility Dog Food
#  Scraped: Multi-Benefit + Dental Adult 1+ Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Dental Adult 1+ Medium And Large Breed Dry Dog Food
#  Scraped: r/d Dog Food
#  Scraped: c/d Multicare + Metabolic Dry Dog Food Original Bag
#  Scraped: Perfect Weight Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Sensitive Stomach & Skin Adult Small & Mini Breed Dry Dog Food Chicken
#  Scraped: j/d Dry Dog Food Original
#  Scraped: Perfect Weight Wet Dog Food with Chicken & Vegetables
#  Scraped: k/d + Mobility Stew for Dogs
#  Scraped: i/d Dog Food
#  Scraped: Light Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Adult Wet Dog Food with Beef
#  Scraped: Healthy Mobility Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Senior Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Light Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Perfect Weight Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: i/d Low Fat Dog Food
#  Scraped: Mature Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: r/d Weight Reduction Dog Food
#  Scraped: Multi-Benefit Puppy Medium Dry Food
#  Scraped: c/d Multicare Wet Dog Food
#  Scraped: Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Adult Wet Dog Food with Chicken
#  Scraped: z/d Mini Food Sensitivities Dry Dog Food Original Bag
#  Scraped: i/d Sensitive Dog Food
#  Scraped: i/d Digestive Care Wet Dog Food with Turkey Can
#  Scraped: i/d Low Fat Digestive Care Wet Dog Food Original Can
#  Scraped: Metabolic Weight Loss & Maintenance Wet Dog Food with Chicken Can
#  Scraped: Light Mature Adult Small & Mini Mini Breed Dry Dog Food with Chicken
#  Scraped: k/d + Mobility Dog Food
#  Scraped: Perfect Weight Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Healthy Mobility Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: w/d Wet Dog Food with Chicken
#  Scraped: Multi-Benefit + Senior Health Mature Adult Medium & Large Dry Dog Food
#  Scraped: u/d Wet Dog Food Original
#  Scraped: w/d Dry Dog Food with Chicken
#  Scraped: j/d Reduced Calorie Dry Dog Food
#  Scraped: Perfect Digestion Adult Large Breed Dry Dog Food Chicken & Brown Rice
#  Scraped: Puppy Wet Dog Food with Chicken
#  Scraped: Derm Complete Puppy Dry Dog Food Original
#  Scraped: Multi-Benefit Adult Wet Dog Food
#  Scraped: z/d Food Sensitivities Dry Dog Food Original Bag
#  Scraping complete. Data saved to UK_first.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Load product URLs
df_links = pd.read_csv("UK_links.csv")
all_data = []

for url in df_links['Link']:
    try:
        response = requests.get(url, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")

        # --- Product Title & Description ---
        title_elem = soup.select_one("div.productAwareRichText h1")
        desc_elem = soup.select_one("div.productAwareRichText p")
        product_title = title_elem.get_text(strip=True) if title_elem else "N/A"
        product_description = desc_elem.get_text(strip=True) if desc_elem else "N/A"

        # --- Description Rows (Need/Preference, Flavour, Sizes, etc.) ---
        attributes = {}
        for row in soup.select("div.pdp-2023-description-row"):
            divs = row.find_all("div", recursive=False)
            if len(divs) >= 2:
                key = divs[0].get_text(strip=True).rstrip(":")
                value = divs[1].get_text(strip=True)
                attributes[key] = value

        # --- Alternate Product Recommendation ---
        alt_elem = soup.find("div", class_="articleList-title")
        alternate_product = alt_elem.get_text(strip=True) if alt_elem else "N/A"

        # --- Accordion Data ---
        accordion_data = {
            "Key Benefits": "N/A",
            "Recommended for": "N/A",
            "Ingredients": "N/A",
            "Helpful Tips": "N/A",
            "Nutrition and Caloric Content": {}
        }

        for h3 in soup.select("h3.accordion-title.component"):
            title_text = h3.get_text(strip=True)
            content_div = h3.find_parent("li").find_next("div", class_="accordion-content-wrapper")
            content = content_div.get_text(" ", strip=True) if content_div else "N/A"

            if "nutrition" in title_text.lower():
                for table in content_div.find_all("table"):
                    for row in table.find_all("tr"):
                        cells = row.find_all("td")
                        if len(cells) == 2:
                            nutrient = cells[0].get_text(strip=True)
                            value = cells[1].get_text(strip=True)
                            accordion_data["Nutrition and Caloric Content"][nutrient] = value
            else:
                for key in accordion_data:
                    if key.lower() in title_text.lower():
                        accordion_data[key] = content

        # --- Combine and Save ---
        product_data = {
            "URL": url,
            "Product Title": product_title,
            "Product Description": product_description,
            "Need/Preference": attributes.get("Need/Preference", "N/A"),
            "Alternate Product Recommendation": alternate_product,
            "Flavour": attributes.get("Flavour", "N/A"),
            "Sizes": attributes.get("Sizes", "N/A"),
            "Breed Size": attributes.get("Breed size", "N/A"),
            "Lifestage": attributes.get("Lifestage", "N/A"),
            "Food Form": attributes.get("Food Form", "N/A"),
            "Key Benefits": accordion_data["Key Benefits"],
            "Recommended for": accordion_data["Recommended for"],
            "Ingredients": accordion_data["Ingredients"],
            "Helpful Tips": accordion_data["Helpful Tips"],
            **accordion_data["Nutrition and Caloric Content"]
        }

        all_data.append(product_data)
        print(f" Scraped: {product_title}")
        time.sleep(random.uniform(1.2, 2.5))

    except Exception as e:
        print(f" Failed on {url}: {e}")
        continue

# Save output
df = pd.DataFrame(all_data)
df.to_csv("UK_second.csv", index=False)
print(" Scraping complete. Saved to UK_second.csv")
# Out:
#  Scraped: k/d Kidney Care Wet Dog Food Original Can
#  Scraped: l/d Wet Dog Food Original
#  Scraped: Adult Large Breed Dry Dog Food with Lamb & Rice
#  Scraped: Medium Mature Adult 7+ Dog Food with Chicken Dry Bag
#  Scraped: t/d Mini Dog Food
#  Scraped: Medium Puppy Food
#  Scraped: d/d Food Sensitivities Dry Dog Food with Duck & Rice Bag
#  Scraped: Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Mature Adult Medium Dog Food
#  Scraped: Light Adult Wet Dog Food with Chicken
#  Scraped: b/d Brain Ageing Care Dry Dog Food with Chicken Bag
#  Scraped: u/d Dry Dog Food Original
#  Scraped: t/d Dog Food
#  Scraped: Oral Care Adult Dry Dog Food with Chicken
#  Scraped: l/d Dry Dog Food Original
#  Scraped: k/d Dog Food
#  Scraped: Light Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Puppy Medium Breed Dry Dog Food with Lamb & Rice
#  Scraped: Adult Wet Dog Food with Turkey
#  Scraped: Adult Medium Breed Dry Dog Food with Lamb & Rice
#  Scraped: Puppy Large Breed Dry Dog Food with Chicken
#  Scraped: Healthy Weight Dog Treats
#  Scraped: Hypoallergenic Dog Treats
#  Scraped: c/d Multicare Dry Dog Food with Chicken Bag
#  Scraped: Perfect Weight Adult Small & Mini Breed Dog Mousse with Turkey
#  Scraped: Mature Adult Multipack Wet Dog Food with Chicken & Beef
#  Scraped: Puppy Multipack Wet Dog Food with Chicken & Beef
#  Scraped: i/d Stress Mini Dog Food
#  Scraped: Adult Multipack Wet Dog Food with Chicken, Turkey & Beef
#  Scraped: Multi-Benefit + Senior Health Mature Adult Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult Wet Dog Food
#  Scraped: Multi-Benefit Puppy Wet Food
#  Scraped: Perfect Digestion Adult Small & Mini Breed Dog Mousse with Turkey
#  Scraped: Small & Mini Breed Adult Dog Mousse with Chicken
#  Scraped: j/d Wet Dog Food with Chicken
#  Scraped: k/d + Mobility Dog Food
#  Scraped: i/d Stress Wet Dog Food with Chicken
#  Scraped: Puppy Small & Mini Breed Dry Food with Chicken
#  Scraped: Gastrointestinal Biome Mini Dry Dog Food with Chicken Bag
#  Scraped: Senior Vitality Mature Adult Small & Mini Breed Dry Dog Food with Chicken & Rice
#  Scraped: Perfect Digestion Puppy Large Breed Dry Dog Food Chicken & Brown Rice
#  Scraped: Perfect Digestion Puppy Small & Mini Dry Dog Food Chicken & Brown Rice
#  Scraped: Hypoallergenic Adult Large Breed Dry Dog Food with Salmon
#  Scraped: Perfect Digestion Puppy Medium Breed Dry Food Chicken & Brown Rice
#  Scraped: Metabolic + Mobility Weight Management Dog Food
#  Scraped: Hypoallergenic Adult Medium Breed Dry Dog Food with Salmon
#  Scraped: Hypoallergenic Adult Small & Mini Breed Dry Dog Food with Salmon
#  Scraped: On-Care Stew for Dogs
#  Scraped: Gastrointestinal Biome Wet Dog Food with Chicken
#  Scraped: On-Care Dry Dog Food
#  Scraped: Derm Complete Dry Dog Food Original
#  Scraped: Metabolic Weight Management Dog Food
#  Scraped: Derm Complete Skin Care & Food Sensitivities Wet Dog Food Original Can
#  Scraped: Large Breed Mature Adult Dog Food
#  Scraped: Metabolic + Mobility Mini Dog Food
#  Scraped: Perfect Weight & Active Mobility Adult Large Dry Dog Food Chicken
#  Scraped: Perfect Weight & Active Mobility Small & Mini Dry Dog Food Chicken
#  Scraped: Perfect Digestion Adult Small & Mini Dry Dog Food Chicken & Brown Rice
#  Scraped: Multi-Benefit Adult Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Large Breed Dry Dog Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Large Breed Dry Dog Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Small & Mini Dry Dog Food
#  Scraped: a/d Dog/Cat Food
#  Scraped: Perfect Digestion Medium Adult 1+ Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Small & Mini Dry Dog Food
#  Scraped: Perfect Digestion Adult Dog Food
#  Scraped: Derm Complete Mini Dog Food
#  Scraped: Multi-Benefit Adult Medium Dry Dog Food
#  Scraped: Multi-Benefit + Weight Adult 1+ Medium Dry Dog Food
#  Scraped: Multi-Benefit Puppy Small & Mini Dry Food
#  Scraped: Multi-Benefit + Digestion Adult 1+ Medium Dry Dog Food with Chicken Bag
#  Scraped: Gastrointestinal Biome Stew for Dogs with Chicken & added Carrots Can
#  Scraped: Perfect Weight & Active Mobility Adult Medium Dry Dog Food Chicken
#  Scraped: k/d Early Stage Dog Food
#  Scraped: Gastrointestinal Biome Dry Dog Food with Chicken Bag
#  Scraped: Metabolic Stew for Dog with Chicken & Vegetables
#  Scraped: i/d Digestive Care Dog Food
#  Scraped: k/d Stew for Dogs
#  Scraped: Light Mature Adult Medium Dry Dog Food with Chicken Bag
#  Scraped: i/d Stress Mini Stew for Dogs
#  Scraped: d/d Food Sensitivities Wet Dog Food Duck Can
#  Scraped: Sensitive Stomach & Skin Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Multi-Benefit Puppy Large Breed Dry Food
#  Scraped: i/d Low Fat Digestive Care Dog Food
#  Scraped: c/d Multicare Urinary Care Stew for Dog Food with Chicken & added Vegetables Can
#  Scraped: Metabolic Mini Dog Food
#  Scraped: Adult Small & Mini Breed Dry Dog Food with Lamb & Rice
#  Scraped: z/d Food Sensitivities Dog Wet Food Original Can
#  Scraped: Healthy Mobility Adult Large Breed Adult Dry Dog Food with Chicken
#  Scraped: Mature Adult Wet Dog Food with Chicken
#  Scraped: Metabolic Dry Dog Food with Chicken
#  Scraped: Metabolic + Mobility Dog Food
#  Scraped: Multi-Benefit + Dental Adult 1+ Small & Mini Dry Dog Food
#  Scraped: Multi-Benefit + Dental Adult 1+ Medium And Large Breed Dry Dog Food
#  Scraped: r/d Dog Food
#  Scraped: c/d Multicare + Metabolic Dry Dog Food Original Bag
#  Scraped: Perfect Weight Adult Large Breed Dry Dog Food with Chicken
#  Scraped: Sensitive Stomach & Skin Adult Small & Mini Breed Dry Dog Food Chicken
#  Scraped: j/d Dry Dog Food Original
#  Scraped: Perfect Weight Wet Dog Food with Chicken & Vegetables
#  Scraped: k/d + Mobility Stew for Dogs
#  Scraped: i/d Dog Food
#  Scraped: Light Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Adult Wet Dog Food with Beef
#  Scraped: Healthy Mobility Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Senior Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Light Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Perfect Weight Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: i/d Low Fat Dog Food
#  Scraped: Mature Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: r/d Weight Reduction Dog Food
#  Scraped: Multi-Benefit Puppy Medium Dry Food
#  Scraped: c/d Multicare Wet Dog Food
#  Scraped: Adult Small & Mini Breed Dry Dog Food with Chicken
#  Scraped: Adult Wet Dog Food with Chicken
#  Scraped: z/d Mini Food Sensitivities Dry Dog Food Original Bag
#  Scraped: i/d Sensitive Dog Food
#  Scraped: i/d Digestive Care Wet Dog Food with Turkey Can
#  Scraped: i/d Low Fat Digestive Care Wet Dog Food Original Can
#  Scraped: Metabolic Weight Loss & Maintenance Wet Dog Food with Chicken Can
#  Scraped: Light Mature Adult Small & Mini Mini Breed Dry Dog Food with Chicken
#  Scraped: k/d + Mobility Dog Food
#  Scraped: Perfect Weight Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: Healthy Mobility Adult Medium Breed Dry Dog Food with Chicken
#  Scraped: w/d Wet Dog Food with Chicken
#  Scraped: Multi-Benefit + Senior Health Mature Adult Medium & Large Dry Dog Food
#  Scraped: u/d Wet Dog Food Original
#  Scraped: w/d Dry Dog Food with Chicken
#  Scraped: j/d Reduced Calorie Dry Dog Food
#  Scraped: Perfect Digestion Adult Large Breed Dry Dog Food Chicken & Brown Rice
#  Scraped: Puppy Wet Dog Food with Chicken
#  Scraped: Derm Complete Puppy Dry Dog Food Original
#  Scraped: Multi-Benefit Adult Wet Dog Food
#  Scraped: z/d Food Sensitivities Dry Dog Food Original Bag
#  Scraping complete. Saved to UK_second.csv

# %%
import re
for row in all_data:
    tips = row.get("Helpful Tips", "")
    match = re.split(r'(?i)kibble size', tips)
    if match:
        row["Helpful Tips"] = match[0].strip()

# Save output
df = pd.DataFrame(all_data)

# %%
for row in all_data:
    benefits = row.get("Key Benefits", "")
    match = re.split(r'(?i)how it helps|recommended for', benefits)
    if match:
        row["Key Benefits"] = match[0].strip()
        
df = pd.DataFrame(all_data)

# %%
for row in all_data:
    # Helpful Tips
    tips = row.get("Helpful Tips", "")
    match = re.split(r'(?i)kibble size', tips)
    if match:
        row["Helpful Tips"] = match[0].strip()

    # Key Benefits
    benefits = row.get("Key Benefits", "")
    benefits = re.sub(r'(?i)^key benefits\s*', '', benefits)
    match = re.split(r'(?i)how it helps|recommended for', benefits)
    if match:
        row["Key Benefits"] = match[0].strip()

    # Ingredients
    ingredients = row.get("Ingredients", "")
    ingredients = re.sub(
        r'(?i)^natural ingredients for a long, happy life.*?life\.', '', ingredients).strip()
    row["Ingredients"] = ingredients

df = pd.DataFrame(all_data)

# %%
for row in all_data:
    # Ingredients cleanup
    ingredients = row.get("Ingredients", "")

    
    # Обрезать всё после "About Our Ingredients"
    match = re.split(r'(?i)about our ingredients', ingredients)
    if match:
        ingredients = match[0].strip()
    
    row["Ingredients"] = ingredients

df = pd.DataFrame(all_data)

# %%
for row in all_data:
    tips = row.get("Helpful Tips", "")

    # Удаляем "FEEDING INSTRUCTIONS:" или "HELPFUL TIPS" в начале строки
    tips = re.sub(r'(?i)^(feeding instructions:|helpful tips)\s*', '', tips)

    row["Helpful Tips"] = tips.strip()
df = pd.DataFrame(all_data)

# %%
if "Nutrient" in df.columns:
    df = df.drop(columns=["Nutrient"])

# %%
df.to_csv("UK_second.csv", index=False)

# %% [markdown]
# Third

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Load your existing product links CSV
df_links = pd.read_csv("UK_links.csv")

# Define function to scrape a single product page
def scrape_product_page(url):
    result = {
        "URL": url,
        "Product title": "",
        "Product description": "",
        "Need/preference": "",
        "Alternate product recommendation": "",
        "Flavour": "",
        "Sizes": "",
        "Breed sizes": "",
        "Lifestage": "",
        "Food form": "",
        "Key benefits": "",
        "Recommended for": "",
        "Not recommended for": "",
        "Ingredients": "",
        "Helpful tips": "",
        "Nutrition and caloric content": ""
    }

    try:
        res = requests.get(url)
        if res.status_code != 200:
            return result  # Return blank if failed

        soup = BeautifulSoup(res.content, "html.parser")

        # Product Title
        h1_tag = soup.find("h1")
        if h1_tag:
            result["Product title"] = h1_tag.get_text(strip=True)

        # Product Description
        desc = soup.find("div", class_="productAwareRichText")
        if desc:
            p = desc.find("p")
            if p:
                result["Product description"] = p.get_text(strip=True)

        # Description details by labels
        detail_sections = soup.find_all("div", class_="productAwareRichText")
        for section in detail_sections:
            texts = section.get_text(strip=True)
            if "Flavour" in texts:
                result["Flavour"] = texts.replace("Flavour", "").strip()
            elif "Breed Size" in texts:
                result["Breed sizes"] = texts.replace("Breed Size", "").strip()
            elif "Food Form" in texts:
                result["Food form"] = texts.replace("Food Form", "").strip()
            elif "Lifestage" in texts:
                result["Lifestage"] = texts.replace("Lifestage", "").strip()
            elif "Sizes" in texts:
                result["Sizes"] = texts.replace("Sizes", "").strip()

        # Key Benefits
        key_benefits_section = soup.find("div", id=lambda x: x and "accordion-content" in x)
        if key_benefits_section:
            ul = key_benefits_section.find("ul")
            if ul:
                result["Key benefits"] = "; ".join([li.get_text(strip=True) for li in ul.find_all("li")])

        # Recommended and Not Recommended
        for div in soup.find_all("div", class_="richText-content"):
            if div.find("h3") and "Recommended for" in div.get_text():
                result["Recommended for"] = div.find_next("p").get_text(strip=True)
            if div.find("h3") and "Not recommended for" in div.get_text():
                result["Not recommended for"] = div.find_next("p").get_text(strip=True)

        # Helpful tips
        for h3 in soup.find_all("h3"):
            if "Transitioning to Hill" in h3.get_text():
                tip = h3.find_next("p")
                if tip:
                    result["Helpful tips"] = tip.get_text(strip=True)

        # Ingredients and Nutrition placeholder (you can expand with more specific search logic later)
        ingredients_anchor = soup.find("a", {"id": "ingredients"})
        if ingredients_anchor:
            ingredients_text = ingredients_anchor.find_next("p")
            if ingredients_text:
                result["Ingredients"] = ingredients_text.get_text(strip=True)

        # Nutrition and caloric content - similar logic, locate anchor or heading and extract following table or text

    except Exception as e:
        print(f"Error scraping {url}: {e}")

    return result

# Scrape all product pages
product_data = []
for i, row in df_links.iterrows():
    url = row["Link"]
    print(f"Scraping {i+1}/{len(df_links)}: {url}")
    product_data.append(scrape_product_page(url))
    time.sleep(random.uniform(2, 4))  

# Save the data to a new CSV
df_UK3 = pd.DataFrame(product_data)
df_UK3.to_csv("UK_third.csv", index=False)
# Out:
# Scraping 1/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-kd-with-chicken-canned
# Scraping 2/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-ld-canned
# Scraping 3/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-advanced-fitness-large-breed-lamb-and-rice-dry
# Scraping 4/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-7-plus-active-longevity-medium-with-chicken-dry
# Scraping 5/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-td-mini-dry
# Scraping 6/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-healthy-development-medium-chicken-dry
# Scraping 7/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-dd-duck-and-rice-dry
# Scraping 8/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-advanced-fitness-large-breed-with-chicken-dry
# Scraping 9/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-7-plus-active-longevity-medium-lamb-and-rice-dry
# Scraping 10/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-light-canned
# Scraping 11/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-bd-dry
# Scraping 12/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-ud-dry
# Scraping 13/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-td-dry
# Scraping 14/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-oral-care-chicken-dry
# Scraping 15/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-ld-dry
# Scraping 16/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-kd-dry
# Scraping 17/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-light-large-breed-chicken-dry
# Scraping 18/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-healthy-development-lamb-and-rice-dry
# Scraping 19/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-medium-savoury-turkey-canned
# Scraping 20/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-advanced-fitness-medium-lamb-and-rice-dry
# Scraping 21/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-healthy-development-large-breed-chicken-dry
# Scraping 22/135: https://www.hillspet.co.uk/dog-food/hills-canine-healthy-weight-dog-treats
# Scraping 23/135: https://www.hillspet.co.uk/dog-food/hills-canine-hypoallergenic-dog-treats
# Scraping 24/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-cd-multicare-dry
# Scraping 25/135: https://www.hillspet.co.uk/dog-food/sd-canine-adult-perfect-weight-small-mini-turkey-canned
# Scraping 26/135: https://www.hillspet.co.uk/dog-food/sp-canine-mature-adult-chicken-beef-canned-multipack
# Scraping 27/135: https://www.hillspet.co.uk/dog-food/sp-canine-puppy-chicken-beef-canned-multipack
# Scraping 28/135: https://www.hillspet.co.uk/dog-food/pd-canine-id-stress-mini-chicken-dry
# Scraping 29/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-chicken-turkey-beef-canned-multipack
# Scraping 30/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-senior-mature-adult-small-mini-dog-food-chicken-dry
# Scraping 31/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-adult-multi-benefit-plus-weight-chicken-vegetables-canned
# Scraping 32/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-puppy-multi-benefit-chicken-canned
# Scraping 33/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-digestion-small-mini-turkey-canned
# Scraping 34/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-small-mini-chicken-canned
# Scraping 35/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-jd-with-chicken-canned
# Scraping 36/135: https://www.hillspet.co.uk/dog-food/pd-canine-kd-plus-mobility-chicken-canned
# Scraping 37/135: https://www.hillspet.co.uk/dog-food/pd-canine-id-stress-mini-chicken-canned
# Scraping 38/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-small-and-miniature-chicken-dry
# Scraping 39/135: https://www.hillspet.co.uk/dog-food/pd-gastrointestinal-biome-canine-small-bites-dry
# Scraping 40/135: https://www.hillspet.co.uk/dog-food/sp-canine-senior-vitality-adult-7-plus-small-mini-chicken-rice-dry
# Scraping 41/135: https://www.hillspet.co.uk/dog-food/sd-canine-puppy-perfect-digestion-large-breed-chicken-brown-rice-dry
# Scraping 42/135: https://www.hillspet.co.uk/dog-food/sd-canine-puppy-perfect-digestion-small-mini-chicken-brown-rice-dry
# Scraping 43/135: https://www.hillspet.co.uk/dog-food/sp-canine-hypoallergenic-large-breed-adult-salmon-dry
# Scraping 44/135: https://www.hillspet.co.uk/dog-food/sd-canine-puppy-perfect-digestion-medium-chicken-brown-rice-dry
# Scraping 45/135: https://www.hillspet.co.uk/dog-food/pd-canine-metabolic-plus-mobility-canned
# Scraping 46/135: https://www.hillspet.co.uk/dog-food/sp-canine-hypoallergenic-medium-adult-salmon-dry
# Scraping 47/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-hypoallergenic-small-mini-adult-salmon-dry
# Scraping 48/135: https://www.hillspet.co.uk/dog-food/pd-canine-on-care-chicken-stew
# Scraping 49/135: https://www.hillspet.co.uk/dog-food/pd-canine-gastrointestinal-biome-with-chicken-canned
# Scraping 50/135: https://www.hillspet.co.uk/dog-food/pd-canine-on-care-chicken-dry
# Scraping 51/135: https://www.hillspet.co.uk/dog-food/pd-canine-derm-complete-dry
# Scraping 52/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-metabolic-lamb-and-rice-dry
# Scraping 53/135: https://www.hillspet.co.uk/dog-food/pd-canine-derm-complete-canned
# Scraping 54/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-6-plus-active-longevity-large-breed-with-chicken-dry
# Scraping 55/135: https://www.hillspet.co.uk/dog-food/pd-canine-metabolic-plus-mobility-mini-dry
# Scraping 56/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-weight-and-active-mobility-large-breed-chicken-dry
# Scraping 57/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-weight-and-active-mobility-small-mini-chicken-dry
# Scraping 58/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-digestion-small-mini-chicken-brown-rice-dry
# Scraping 59/135: https://www.hillspet.co.uk/dog-food/ve-canine-adult-small-breed-with-lamb-rice-dry
# Scraping 60/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-neutereddog-adult-large-breed-dog-food-chicken-dry
# Scraping 61/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-healthy-digestive-biome-adult-large-dry
# Scraping 62/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-healthy-digestive-biome-adult-small-mini-dry
# Scraping 63/135: https://www.hillspet.co.uk/dog-food/pd-canine-feline-prescription-diet-ad-canned
# Scraping 64/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-digestion-medium-breed-chicken-brown-rice-dry
# Scraping 65/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-neutereddog-adult-small-breed-mini-dog-food-chicken-dry
# Scraping 66/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-digestion-chicken-vegetables-canned
# Scraping 67/135: https://www.hillspet.co.uk/dog-food/pd-canine-derm-complete-mini-dry
# Scraping 68/135: https://www.hillspet.co.uk/dog-food/ve-canine-adult-medium-with-lamb-rice-dry
# Scraping 69/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-neutereddog-adult-medium-dog-food-chicken-dry
# Scraping 70/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-small-breed-mini-puppy-food-chicken-dry
# Scraping 71/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-healthy-digestive-biome-adult-medium-dry
# Scraping 72/135: https://www.hillspet.co.uk/dog-food/pd-canine-gastrointestinal-biome-chicken-vegetable-stew-canned
# Scraping 73/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-weight-and-active-mobility-medium-chicken-dry
# Scraping 74/135: https://www.hillspet.co.uk/dog-food/pd-canine-kd-early-stage-dry
# Scraping 75/135: https://www.hillspet.co.uk/dog-food/pd-gastrointestinal-biome-canine-dry
# Scraping 76/135: https://www.hillspet.co.uk/dog-food/pd-metabolic-canine-vegetable-and-chicken-stew-canned
# Scraping 77/135: https://www.hillspet.co.uk/dog-food/pd-id-canine-chicken-and-vegetable-stew-canned
# Scraping 78/135: https://www.hillspet.co.uk/dog-food/pd-kd-canine-chicken-and-vegetable-stew-canned
# Scraping 79/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-7-plus-light-medium-with-chicken-dry
# Scraping 80/135: https://www.hillspet.co.uk/dog-food/pd-id-canine-stress-rice-vegetable-and-chicken-stew-canned
# Scraping 81/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-dd-duck-canned
# Scraping 82/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-sensitive-stomach-and-skin-with-chicken-dry
# Scraping 83/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-puppy-large-breed-dry
# Scraping 84/135: https://www.hillspet.co.uk/dog-food/pd-id-low-fat-canine-rice-vegetable-and-chicken-stew-canned
# Scraping 85/135: https://www.hillspet.co.uk/dog-food/pd-cd-multicare-canine-chicken-and-vegetable-canned
# Scraping 86/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-metabolic-small-breed-dry
# Scraping 87/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-small-and-miniature-lamb-rice-dry
# Scraping 88/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-zd-mini-original-canned
# Scraping 89/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-healthy-mobility-large-with-chicken-dry
# Scraping 90/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-7-plus-medium-savoury-chicken-canned
# Scraping 91/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-metabolic-original-dry
# Scraping 92/135: https://www.hillspet.co.uk/dog-food/pd-canine-metabolic-plus-mobility-with-chicken-dry
# Scraping 93/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-adult-mini-dry
# Scraping 94/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-canine-adult-dry
# Scraping 95/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-rd-with-chicken-dry
# Scraping 96/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-metabolic-plus-urinary-original-dry
# Scraping 97/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-perfect-weight-large-breed-with-chicken-dry
# Scraping 98/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-small-and-miniature-sensitive-stomach-skin-with-chicken-dry
# Scraping 99/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-jd-chicken-dry
# Scraping 100/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-weight-with-chicken-and-vegetables-canned
# Scraping 101/135: https://www.hillspet.co.uk/dog-food/pd-kd-plus-mobility-canine-chicken-and-vegetable-stew-canned
# Scraping 102/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-id-with-chicken-dry
# Scraping 103/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-light-with-chicken-dry
# Scraping 104/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-formula-savoury-beef-canned
# Scraping 105/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-healthy-mobility-mini-with-chicken-dry
# Scraping 106/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-senior-11-plus-small-and-miniature-original-dry
# Scraping 107/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-small-and-miniature-light-original-dry
# Scraping 108/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-advanced-fitness-med-chicken-dry
# Scraping 109/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-perfect-weight-mini-with-chicken-dry
# Scraping 110/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-id-low-fat-dry
# Scraping 111/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-7-plus-small-and-miniature-dry
# Scraping 112/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-rd-canned
# Scraping 113/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-puppy-dry
# Scraping 114/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-cd-multicare-canned
# Scraping 115/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-small-and-miniature-chicken-turkey-dry
# Scraping 116/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-medium-savoury-chicken-canned
# Scraping 117/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-zd-mini-original-dry
# Scraping 118/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-id-sensitive-dry
# Scraping 119/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-id-turkey-canned
# Scraping 120/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-id-low-fat-canned
# Scraping 121/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-metabolic-original-canned
# Scraping 122/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-mature-adult-7-plus-mini-light-with-chicken-dry
# Scraping 123/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-kd-plus-mobility-original-dry
# Scraping 124/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-perfect-weight-medium-dry
# Scraping 125/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-adult-healthy-mobility-medium-with-chicken-dry
# Scraping 126/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-wd-canned
# Scraping 127/135: https://www.hillspet.co.uk/dog-food/ve-canine-vetessentials-senior-mature-adult-medium-large-dog-food-chicken-dry
# Scraping 128/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-ud-canned
# Scraping 129/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-wd-chicken-dry
# Scraping 130/135: https://www.hillspet.co.uk/dog-food/pd-jd-canine-reduced-calorie-with-chicken-dry
# Scraping 131/135: https://www.hillspet.co.uk/dog-food/sp-canine-adult-perfect-digestion-large-breed-chicken-brown-rice-dry
# Scraping 132/135: https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-medium-savoury-chicken-canned
# Scraping 133/135: https://www.hillspet.co.uk/dog-food/pd-canine-puppy-derm-complete-dry
# Scraping 134/135: https://www.hillspet.co.uk/dog-food/ve-canine-adult-with-tender-chicken-vegetables-canned
# Scraping 135/135: https://www.hillspet.co.uk/dog-food/pd-canine-prescription-diet-zd-ultra-allergen-free-dry

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Загрузка ссылок
df_links = pd.read_csv("UK_links.csv")
all_data = []

for url in df_links['Link']:
    try:
        response = requests.get(url, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")

        # Title
        title_elem = soup.select_one("div.productAwareRichText h1")
        product_title = title_elem.get_text(strip=True) if title_elem else "N/A"

        # Nutrition and caloric content
        nutrition_kcal = "N/A"
        for h3 in soup.select("h3.accordion-title.component"):
            if "nutrition" in h3.get_text(strip=True).lower():
                content_div = h3.find_parent("li").find_next("div", class_="accordion-content-wrapper")
                if content_div:
                    kcal_div = content_div.find("div", class_="richText-content")
                    if kcal_div:
                        nutrition_kcal = kcal_div.get_text(strip=True)
                break  

        all_data.append({
            "URL": url,
            "Product Title": product_title,
            "Nutrition and caloric content": nutrition_kcal
        })

        print(f" {product_title}")
        time.sleep(random.uniform(1.2, 2.5))

    except Exception as e:
        print(f" Failed on {url}: {e}")
        continue

df_UK4 = pd.DataFrame(all_data)
df_UK4.to_csv("UK_fourth.csv", index=False)
print(" Saved to UK_fourth.csv")
# Out:
#  k/d Kidney Care Wet Dog Food Original Can
#  l/d Wet Dog Food Original
#  Adult Large Breed Dry Dog Food with Lamb & Rice
#  Medium Mature Adult 7+ Dog Food with Chicken Dry Bag
#  t/d Mini Dog Food
#  Medium Puppy Food
#  d/d Food Sensitivities Dry Dog Food with Duck & Rice Bag
#  Adult Large Breed Dry Dog Food with Chicken
#  Mature Adult Medium Dog Food
#  Light Adult Wet Dog Food with Chicken
#  b/d Brain Ageing Care Dry Dog Food with Chicken Bag
#  u/d Dry Dog Food Original
#  t/d Dog Food
#  Oral Care Adult Dry Dog Food with Chicken
#  l/d Dry Dog Food Original
#  k/d Dog Food
#  Light Adult Large Breed Dry Dog Food with Chicken
#  Puppy Medium Breed Dry Dog Food with Lamb & Rice
#  Adult Wet Dog Food with Turkey
#  Adult Medium Breed Dry Dog Food with Lamb & Rice
#  Puppy Large Breed Dry Dog Food with Chicken
#  Healthy Weight Dog Treats
#  Hypoallergenic Dog Treats
#  c/d Multicare Dry Dog Food with Chicken Bag
#  Perfect Weight Adult Small & Mini Breed Dog Mousse with Turkey
#  Mature Adult Multipack Wet Dog Food with Chicken & Beef
#  Puppy Multipack Wet Dog Food with Chicken & Beef
#  i/d Stress Mini Dog Food
#  Adult Multipack Wet Dog Food with Chicken, Turkey & Beef
#  Multi-Benefit + Senior Health Mature Adult Small & Mini Dry Dog Food
#  Multi-Benefit + Weight Adult Wet Dog Food
#  Multi-Benefit Puppy Wet Food
#  Perfect Digestion Adult Small & Mini Breed Dog Mousse with Turkey
#  Small & Mini Breed Adult Dog Mousse with Chicken
#  j/d Wet Dog Food with Chicken
#  k/d + Mobility Dog Food
#  i/d Stress Wet Dog Food with Chicken
#  Failed on https://www.hillspet.co.uk/dog-food/sp-canine-science-plan-puppy-small-and-miniature-chicken-dry: HTTPSConnectionPool(host='www.hillspet.co.uk', port=443): Read timed out. (read timeout=15)
#  Gastrointestinal Biome Mini Dry Dog Food with Chicken Bag
#  Senior Vitality Mature Adult Small & Mini Breed Dry Dog Food with Chicken & Rice
#  Perfect Digestion Puppy Large Breed Dry Dog Food Chicken & Brown Rice
#  Perfect Digestion Puppy Small & Mini Dry Dog Food Chicken & Brown Rice
#  Hypoallergenic Adult Large Breed Dry Dog Food with Salmon
#  Perfect Digestion Puppy Medium Breed Dry Food Chicken & Brown Rice
#  Metabolic + Mobility Weight Management Dog Food
#  Hypoallergenic Adult Medium Breed Dry Dog Food with Salmon
#  Hypoallergenic Adult Small & Mini Breed Dry Dog Food with Salmon
#  On-Care Stew for Dogs
#  Gastrointestinal Biome Wet Dog Food with Chicken
#  On-Care Dry Dog Food
#  Derm Complete Dry Dog Food Original
#  Metabolic Weight Management Dog Food
#  Derm Complete Skin Care & Food Sensitivities Wet Dog Food Original Can
#  Large Breed Mature Adult Dog Food
#  Metabolic + Mobility Mini Dog Food
#  Perfect Weight & Active Mobility Adult Large Dry Dog Food Chicken
#  Perfect Weight & Active Mobility Small & Mini Dry Dog Food Chicken
#  Perfect Digestion Adult Small & Mini Dry Dog Food Chicken & Brown Rice
#  Multi-Benefit Adult Small & Mini Dry Dog Food
#  Multi-Benefit + Weight Adult 1+ Large Breed Dry Dog Food
#  Multi-Benefit + Digestion Adult 1+ Large Breed Dry Dog Food
#  Multi-Benefit + Digestion Adult 1+ Small & Mini Dry Dog Food
#  a/d Dog/Cat Food
#  Perfect Digestion Medium Adult 1+ Dog Food
#  Multi-Benefit + Weight Adult 1+ Small & Mini Dry Dog Food
#  Perfect Digestion Adult Dog Food
#  Derm Complete Mini Dog Food
#  Multi-Benefit Adult Medium Dry Dog Food
#  Multi-Benefit + Weight Adult 1+ Medium Dry Dog Food
#  Multi-Benefit Puppy Small & Mini Dry Food
#  Multi-Benefit + Digestion Adult 1+ Medium Dry Dog Food with Chicken Bag
#  Gastrointestinal Biome Stew for Dogs with Chicken & added Carrots Can
#  Perfect Weight & Active Mobility Adult Medium Dry Dog Food Chicken
#  k/d Early Stage Dog Food
#  Gastrointestinal Biome Dry Dog Food with Chicken Bag
#  Metabolic Stew for Dog with Chicken & Vegetables
#  i/d Digestive Care Dog Food
#  k/d Stew for Dogs
#  Light Mature Adult Medium Dry Dog Food with Chicken Bag
#  i/d Stress Mini Stew for Dogs
#  d/d Food Sensitivities Wet Dog Food Duck Can
#  Sensitive Stomach & Skin Adult Medium Breed Dry Dog Food with Chicken
#  Multi-Benefit Puppy Large Breed Dry Food
#  i/d Low Fat Digestive Care Dog Food
#  c/d Multicare Urinary Care Stew for Dog Food with Chicken & added Vegetables Can
#  Metabolic Mini Dog Food
#  Adult Small & Mini Breed Dry Dog Food with Lamb & Rice
#  z/d Food Sensitivities Dog Wet Food Original Can
#  Healthy Mobility Adult Large Breed Adult Dry Dog Food with Chicken
#  Mature Adult Wet Dog Food with Chicken
#  Metabolic Dry Dog Food with Chicken
#  Metabolic + Mobility Dog Food
#  Multi-Benefit + Dental Adult 1+ Small & Mini Dry Dog Food
#  Multi-Benefit + Dental Adult 1+ Medium And Large Breed Dry Dog Food
#  r/d Dog Food
#  c/d Multicare + Metabolic Dry Dog Food Original Bag
#  Perfect Weight Adult Large Breed Dry Dog Food with Chicken
#  Sensitive Stomach & Skin Adult Small & Mini Breed Dry Dog Food Chicken
#  j/d Dry Dog Food Original
#  Perfect Weight Wet Dog Food with Chicken & Vegetables
#  k/d + Mobility Stew for Dogs
#  i/d Dog Food
#  Light Adult Medium Breed Dry Dog Food with Chicken
#  Adult Wet Dog Food with Beef
#  Healthy Mobility Adult Small & Mini Breed Dry Dog Food with Chicken
#  Senior Small & Mini Breed Dry Dog Food with Chicken
#  Light Adult Small & Mini Breed Dry Dog Food with Chicken
#  Adult Medium Breed Dry Dog Food with Chicken
#  Perfect Weight Adult Small & Mini Breed Dry Dog Food with Chicken
#  i/d Low Fat Dog Food
#  Mature Adult Small & Mini Breed Dry Dog Food with Chicken
#  r/d Weight Reduction Dog Food
#  Multi-Benefit Puppy Medium Dry Food
#  c/d Multicare Wet Dog Food
#  Adult Small & Mini Breed Dry Dog Food with Chicken
#  Adult Wet Dog Food with Chicken
#  z/d Mini Food Sensitivities Dry Dog Food Original Bag
#  i/d Sensitive Dog Food
#  i/d Digestive Care Wet Dog Food with Turkey Can
#  i/d Low Fat Digestive Care Wet Dog Food Original Can
#  Metabolic Weight Loss & Maintenance Wet Dog Food with Chicken Can
#  Light Mature Adult Small & Mini Mini Breed Dry Dog Food with Chicken
#  k/d + Mobility Dog Food
#  Perfect Weight Adult Medium Breed Dry Dog Food with Chicken
#  Healthy Mobility Adult Medium Breed Dry Dog Food with Chicken
#  w/d Wet Dog Food with Chicken
#  Multi-Benefit + Senior Health Mature Adult Medium & Large Dry Dog Food
#  u/d Wet Dog Food Original
#  w/d Dry Dog Food with Chicken
#  j/d Reduced Calorie Dry Dog Food
#  Perfect Digestion Adult Large Breed Dry Dog Food Chicken & Brown Rice
#  Puppy Wet Dog Food with Chicken
#  Derm Complete Puppy Dry Dog Food Original
#  Multi-Benefit Adult Wet Dog Food
#  z/d Food Sensitivities Dry Dog Food Original Bag
#  Saved to UK_fourth.csv

# %%
import csv

# Ожидаемое количество колонок
expected_columns = 93

# Фиксируем строки
cleaned_rows = []

with open("UK_second.csv", encoding="utf-8") as infile:
    reader = csv.reader(infile)
    header = next(reader)
    cleaned_rows.append(header)

    for row in reader:
        if len(row) < expected_columns:
            # Если колонок меньше, дополняем N/A
            row += ["N/A"] * (expected_columns - len(row))
        elif len(row) > expected_columns:
            # Если колонок больше, обрезаем
            row = row[:expected_columns]
        cleaned_rows.append(row)

# Сохраняем в новый CSV
with open("UK_second_fixed.csv", "w", encoding="utf-8", newline="") as outfile:
    writer = csv.writer(outfile)
    writer.writerows(cleaned_rows)

print("Исправленный файл сохранён как UK_second_fixed.csv")
# Out:
# Исправленный файл сохранён как UK_second_fixed.csv

# %%
import pandas as pd
import csv

# Пути к исходному и исправленному файлу
input_file = "UK_second.csv"
fixed_file = "UK_second_fixed.csv"

# Определим ожидаемое количество колонок по заголовку
with open(input_file, encoding="utf-8") as f:
    reader = csv.reader(f)
    header = next(reader)
    expected_columns = len(header)

# Исправим строки: дополним или обрежем до нужного количества колонок
cleaned_rows = [header]
with open(input_file, encoding="utf-8") as f:
    reader = csv.reader(f)
    next(reader)  # пропускаем заголовок
    for row in reader:
        if len(row) < expected_columns:
            row += ["N/A"] * (expected_columns - len(row))
        elif len(row) > expected_columns:
            row = row[:expected_columns]
        cleaned_rows.append(row)

# Сохраним исправленный CSV
with open(fixed_file, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(cleaned_rows)

# Загрузим исправленный файл для подтверждения
df_fixed = pd.read_csv(fixed_file)
df_fixed.shape
# Out:
# (135, 64)

# %%
df_UK4.columns = df_UK4.columns.str.strip()

# %%
df_mer = df.merge(df_UK4[["URL", "Nutrition and caloric content"]], on="URL", how="left")

columns = list(df_mer.columns)
if "Helpful Tips" in columns and "Nutrition and caloric content" in columns:
    columns.remove("Nutrition and caloric content")
    insert_index = columns.index("Helpful Tips") + 1
    columns.insert(insert_index, "Nutrition and caloric content")
    df_mer = df_mer[columns]

final_output = "UK_24.csv"
df_mer.to_csv(final_output, index=False)
final_output
# Out:
# 'UK_24.csv'

# %%
df_mer.columns = df_mer.columns.str.strip().str.lower()
df_UK3.columns = df_UK3.columns.str.strip().str.lower()

# Объединяем по url (берём нужные колонки из df_UK3)
df_merged1 = df_mer.drop(columns=['sizes', 'recommended for'], errors='ignore') \
    .merge(df_UK3[['url', 'sizes', 'recommended for']], on='url', how='left')

df_merged1.to_csv("UK_234.csv", index=False)

# %%
df_UK1.columns = df_UK1.columns.str.strip().str.lower()

df_final = df_merged1.drop(columns=['need/preference', 'alternate product recommendation', 'flavour', 'breed size', 'lifestage', 'food form'], errors='ignore') \
    .merge(df_UK1[['url', 'need/preference', 'alternate product recommendation', 'flavour', 'breed size', 'lifestage', 'food form']], on='url', how='left')

df_final.to_csv("UK_final.csv", index=False)

# %%
df_final
# Out:
#                                                    url  \
# 0    https://www.hillspet.co.uk/dog-food/pd-canine-...
# 1    https://www.hillspet.co.uk/dog-food/pd-canine-...
# 2    https://www.hillspet.co.uk/dog-food/sp-canine-...
# 3    https://www.hillspet.co.uk/dog-food/sp-canine-...
# 4    https://www.hillspet.co.uk/dog-food/pd-canine-...
# ..                                                 ...
# 130  https://www.hillspet.co.uk/dog-food/sp-canine-...
# 131  https://www.hillspet.co.uk/dog-food/sp-canine-...
# 132  https://www.hillspet.co.uk/dog-food/pd-canine-...
# 133  https://www.hillspet.co.uk/dog-food/ve-canine-...
# 134  https://www.hillspet.co.uk/dog-food/pd-canine-...
#
#                                          product title  \
# 0            k/d Kidney Care Wet Dog Food Original Can
# 1                            l/d Wet Dog Food Original
# 2      Adult Large Breed Dry Dog Food with Lamb & Rice
# 3    Medium Mature Adult 7+ Dog Food with Chicken D...
# 4                                    t/d Mini Dog Food
# ..                                                 ...
# 130  Perfect Digestion Adult Large Breed Dry Dog Fo...
# 131                    Puppy Wet Dog Food with Chicken
# 132          Derm Complete Puppy Dry Dog Food Original
# 133                   Multi-Benefit Adult Wet Dog Food
# 134   z/d Food Sensitivities Dry Dog Food Original Bag
#
#                                    product description  \
# 0            k/d Kidney Care Wet Dog Food Original Can
# 1                            l/d Wet Dog Food Original
# 2      Adult Large Breed Dry Dog Food with Lamb & Rice
# 3    Medium Mature Adult 7+ Dog Food with Chicken D...
# 4                                    t/d Mini Dog Food
# ..                                                 ...
# 130  Perfect Digestion Adult Large Breed Dry Dog Fo...
# 131                    Puppy Wet Dog Food with Chicken
# 132          Derm Complete Puppy Dry Dog Food Original
# 133                   Multi-Benefit Adult Wet Dog Food
# 134   z/d Food Sensitivities Dry Dog Food Original Bag
#
#                                           key benefits  \
# 0    When dogs have damage to kidney tissues, the k...
# 1    The liver is your dog's largest internal organ...
# 2    Hill's Science Plan Large Breed Adult dog food...
# 3    HILL'S SCIENCE PLAN Mature Adult Medium dog fo...
# 4    Hill's Prescription Diet t/d Small Bites Dry D...
# ..                                                 ...
# 130  Hill's Science Plan PERFECT DIGESTION LARGE BR...
# 131  Your puppy will love the taste of HILL'S SCIEN...
# 132  Hill's Prescription Diet Derm Complete Puppy D...
# 133  Available exclusively through your veterinaria...
# 134  Food sensitivities and intolerance are potenti...
#
#                                            ingredients  \
# 0    ActivBiome+ Kidney Defense prebiotic blend (0....
# 1    COMPOSITION: Cereals, oils and fats, vegetable...
# 2    Maize, lamb meal, soybean meal, maize gluten m...
# 3    COMPOSITION: Maize, wheat, chicken and turkey ...
# 4    COMPOSITION: Cereals, meat and animal derivati...
# ..                                                 ...
# 130  COMPOSITION: Wheat, maize, chicken and turkey ...
# 131  COMPOSITION: Meat and animal derivatives (chic...
# 132  COMPOSITION: Cereals, eggs and egg derivatives...
# 133  COMPOSITION: Chicken (17%), pork, carrots, ric...
# 134  COMPOSITION: Derivatives of vegetable origin, ...
#
#                                           helpful tips  \
# 0    Feed only this food. It is recommended that ad...
# 1    Ask your veterinarian for specific feeding ins...
# 2    Adjust feeding amounts as necessary to maintai...
# 3    Adjust feeding amounts as necessary to maintai...
# 4    Feed only this food. It is recommended that a ...
# ..                                                 ...
# 130  Feed the daily amount shown; adjust amount to ...
# 131  For puppies/pregnant bitches feed 2 to 4 meals...
# 132  Feed only this food. It is recommended that a ...
# 133  Adjust feeding as necessary to maintain optimu...
# 134  Feed only this food. It is recommended that a ...
#
#                       nutrition and caloric content moisture protein     fat  \
# 0    338.2 kcal (370 g) can, 182.8 kcal (200 g) can     73 %   4.2 %   6.8 %
# 1                            338.2 kcal (370 g) can     74 %   4.9 %   6.1 %
# 2                      3701 kcal/kg (370 kcal/100g)      8 %  21.3 %  14.2 %
# 3                      3682 kcal/kg (368 kcal/100g)      9 %  17.1 %    14 %
# 4                      3533 kcal/kg (353 kcal/100g)      8 %  16.1 %  15.2 %
# ..                                              ...      ...     ...     ...
# 130                    3524 kcal/kg (352 kcal/100g)      8 %  18.4 %  11.7 %
# 131                          367.5 kcal (370 g) can     76 %   6.8 %   5.3 %
# 132                    3720 kcal/kg (372 kcal/100g)      8 %  23.4 %  16.2 %
# 133                            292 kcal (363 g) can      NaN   6.3 %   3.3 %
# 134                    3534 kcal/kg (353 kcal/100g)      8 %  17.6 %  14.4 %
#
#      ... starch bcaa total              sizes  \
# 0    ...    NaN        NaN         180g, 350g
# 1    ...    NaN        NaN               370g
# 2    ...    NaN        NaN               14kg
# 3    ...    NaN        NaN  2.5kg, 14kg, 18kg
# 4    ...    NaN        NaN                3kg
# ..   ...    ...        ...                ...
# 130  ...    NaN        NaN               14kg
# 131  ...    NaN        NaN               370g
# 132  ...    NaN        NaN               12kg
# 133  ...    NaN        NaN               363g
# 134  ...    NaN        NaN          3kg, 10kg
#
#                                        recommended for  \
# 0
# 1
# 2           Large breed adult dogs 1 - 5 years of age.
# 3                   Mature Adult dogs 7+ years of age.
# 4
# ..                                                 ...
# 130  Adult dogs 1 - 5 years to help keep their dige...
# 131  Puppies up to 1 year old and pregnant or nursi...
# 132
# 133          Adult medium breed dogs 1-6 years of age.
# 134
#
#                    need/preference alternate product recommendation  \
# 0                      Kidney Care                       Liver Care
# 1                       Liver Care                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                      Dental Care                   Digestive Care
# ..                             ...                              ...
# 130                            NaN                              NaN
# 131                            NaN                              NaN
# 132  Skin Care, Food Sensitivities                   Digestive Care
# 133                            NaN                              NaN
# 134             Food Sensitivities        Digestive Care, Skin Care
#
#                               flavour                              breed size  \
# 0                            Original                                     NaN
# 1                            Original  Small Breed, Medium Breed, Large Breed
# 2                    with Lamb & Rice                             Large Breed
# 3                        with Chicken                            Medium Breed
# 4                        with Chicken  Small Breed, Medium Breed, Large Breed
# ..                                ...                                     ...
# 130       with Chicken and Brown Rice                             Large Breed
# 131                           Chicken  Small Breed, Medium Breed, Large Breed
# 132                          Original                                     NaN
# 133  with Tender Chicken & Vegetables                            Medium Breed
# 134                          Original               Medium Breed, Large Breed
#
#                   lifestage food form
# 0                       NaN       NaN
# 1                     Adult  Wet Food
# 2                     Adult  Dry Food
# 3                    Senior  Dry Food
# 4             Adult, Senior  Dry Food
# ..                      ...       ...
# 130                   Adult  Dry Food
# 131  Puppy/pregnant/nursing  Wet Food
# 132                   Puppy  Dry Food
# 133                   Adult  Wet Food
# 134                   Adult  Dry Food
#
# [135 rows x 65 columns]

# %%
df_final.columns
# Out:
# Index(['url', 'product title', 'product description', 'key benefits',
#        'ingredients', 'helpful tips', 'nutrition and caloric content',
#        'moisture', 'protein', 'fat', 'carbohydrate (nfe)', 'crude fibre',
#        'crude ash', 'soluble fibre', 'calcium', 'phospohorus', 'potassium',
#        'sodium', 'magnesium', 'taurine', 'vitamin a', 'vitamin c', 'vitamin d',
#        'vitamin e', 'thiamine (vitamin b1)', 'riboflavin (vitamin b2)',
#        'niacin (vitamin b3)', 'pyridoxine (vitamin b6)',
#        'pantothenic acid (vitamin b5)', 'folic acid (vitamin b9)',
#        'vitamin b12 (cobalamin)', 'biotin (vitamin b7)', 'dha', 'epa',
#        'epa + dha', 'omega-3-fatty acids', 'omega-6-fatty acids',
#        'beta-carotene', 'l-carnitine', 'glucosamine', 'chondroitin sulfate',
#        'total dietary fibre', 'iron', 'copper', 'zinc', 'l-arginine',
#        'glutamine + glutamate', 'linoleic acid', 'essential fatty acids',
#        'chloride', 'sulphur', 'hydroxyproline', 'l-lysine',
#        'dl-methionine + l-cystine', 'insoluble fibre', 'starch', 'bcaa total',
#        'sizes', 'recommended for', 'need/preference',
#        'alternate product recommendation', 'flavour', 'breed size',
#        'lifestage', 'food form'],
#       dtype='object')

# %%
df_reorder.columns
# Out:
# Index(['url', 'product title', 'product description', 'food form', 'flavor',
#        'sizes', 'recommended for', 'ingredients', 'feeding tips',
#        'key features', 'caloric content', 'protein', 'fat',
#        'carbohydrate / nfe', 'crude fiber', 'calcium', 'phosphorus',
#        'potassium', 'sodium', 'magnesium', 'vitamin c', 'vitamin e',
#        'total omega-3 fa', 'total omega-6 fa', 'ash', 'vitamin a', 'vitamin d',
#        'beta-carotene', 'epa', 'carnitine', 'dha', 'glucosamine',
#        'chondroitin sulfate', 'total dietary fiber', 'lysine', 'taurine',
#        'linoleic acid', 'chloride', 'bcaa total', 'glutamine + glutamate',
#        'iron', 'copper', 'zinc', 'vitamin k', 'alpha-linolenic acid (ala)'],
#       dtype='object')

# %%
rename_map = {
    'flavor': 'flavour',
    'feeding tips': 'helpful tips',
    'key features': 'key benefits',
    'caloric content': 'nutrition and caloric content',
    'crude fiber': 'crude fibre',
    'carbohydrate / nfe': 'carbohydrate (nfe)',
    'ash': 'crude ash',
    'phosphorus': 'phospohorus',  
    'carnitine': 'l-carnitine',
    'lysine': 'l-lysine',
    'total omega-3 fa': 'omega-3-fatty acids',
    'total omega-6 fa': 'omega-6-fatty acids'
}

# %%
df_reorder.rename(columns=rename_map, inplace=True)

combined_df = pd.concat([df_final, df_reorder], ignore_index=True, sort=False)

# %%
combined_df.to_csv("combined_dataset_clean.csv", index=False, encoding='utf-8')
